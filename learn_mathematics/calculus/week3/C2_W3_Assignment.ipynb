# %% [markdown]
# # Neural Network with Two Layers
#
# Welcome to your week three programming assignment. You are ready to build a neural network with two layers and train it to solve a classification problem.
#
# **After this assignment, you will be able to:**
#
# - Implement a neural network with two layers to a classification problem
# - Implement forward propagation using matrix multiplication
# - Perform backward propagation

# %% [markdown]
# # Table of Contents
#
# - [ 1 - Classification Problem](#1)
# - [ 2 - Neural Network Model with Two Layers](#2)
#   - [ 2.1 - Neural Network Model with Two Layers for a Single Training Example](#2.1)
#   - [ 2.2 - Neural Network Model with Two Layers for Multiple Training Examples](#2.2)
#   - [ 2.3 - Cost Function and Training](#2.3)
#   - [ 2.4 - Dataset](#2.4)
#   - [ 2.5 - Define Activation Function](#2.5)
#     - [ Exercise 1](#ex01)
# - [ 3 - Implementation of the Neural Network Model with Two Layers](#3)
#   - [ 3.1 - Defining the Neural Network Structure](#3.1)
#     - [ Exercise 2](#ex02)
#   - [ 3.2 - Initialize the Model's Parameters](#3.2)
#     - [ Exercise 3](#ex03)
#   - [ 3.3 - The Loop](#3.3)
#     - [ Exercise 4](#ex04)
#     - [ Exercise 5](#ex05)
#     - [ Exercise 6](#ex06)
#   - [ 3.4 - Integrate parts 3.1, 3.2 and 3.3 in nn_model()](#3.4)
#     - [ Exercise 7](#ex07)
#     - [ Exercise 8](#ex08)
# - [ 4 - Optional: Other Dataset](#4)

# %% [markdown]
# ## Packages
#
# First, import all the packages you will need during this assignment.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
# A function to create a dataset.
from sklearn.datasets import make_blobs

# Output of plotting commands is displayed inline within the Jupyter notebook.
# %matplotlib inline 

# Set a seed so that the results are consistent.
np.random.seed(3)

# %% [markdown]
# Load the unit tests defined for this notebook.

# %%
import w3_unittest

# %% [markdown]
# <a name='1'></a>
# ## 1 - Classification Problem

# %% [markdown]
# In one of the labs this week, you trained a neural network with a single perceptron, performing forward and backward propagation. That simple structure was enough to solve a "linear" classification problem - finding a straight line in a plane that would serve as a decision boundary to separate two classes.
#
# Imagine that now you have a more complicated problem: you still have two classes, but one line will not be enough to separate them.

# %%
fig, ax = plt.subplots()
xmin, xmax = -0.2, 1.4
x_line = np.arange(xmin, xmax, 0.1)
# Data points (observations) from two classes.
ax.scatter(0, 0, color="r")
ax.scatter(0, 1, color="b")
ax.scatter(1, 0, color="b")
ax.scatter(1, 1, color="r")
ax.set_xlim([xmin, xmax])
ax.set_ylim([-0.1, 1.1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
# Example of the lines which can be used as a decision boundary to separate two classes.
ax.plot(x_line, -1 * x_line + 1.5, color="black")
ax.plot(x_line, -1 * x_line + 0.5, color="black")
plt.plot()
# Out:
# []

# %% [markdown]
# This logic can appear in many applications. For example, if you train a model to predict whether you should buy a house knowing its size and the year it was built. A big new house will not be affordable, while a small old house will not be worth buying. So, you might be interested in either a big old house, or a small new house.
#
# The one perceptron neural network is not enough to solve such classification problem. Let's look at how you can adjust that model to find the solution.
#
# In the plot above, two lines can serve as a decision boundary. Your intuition might tell you that you should also increase the number of perceptrons. And that is absolutely right! You need to feed your data points (coordinates $x_1$, $x_2$) into two nodes separately and then unify them somehow with another one to make a decision.
#
# Now let's figure out the details, build and train your first multi-layer neural network!

# %% [markdown]
# <a name='2'></a>
# ## 2 - Neural Network Model with Two Layers

# %% [markdown]
# <a name='2.1'></a>
# ### 2.1 - Neural Network Model with Two Layers for a Single Training Example

# %% [markdown]
# <img src="images/nn_model_2_layers.png" style="width:1000px;">

# %% [markdown]
# The input and output layers of the neural network are the same as for one perceptron model, but there is a **hidden layer** now in between them. The training examples $x^{(i)}=\begin{bmatrix}x_1^{(i)} \\ x_2^{(i)}\end{bmatrix}$ from the input layer of size $n_x = 2$ are first fed into the hidden layer of size $n_h = 2$. They are simultaneously fed into the first perceptron with weights $W_1^{[1]}=\begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]}\end{bmatrix}$, bias  $b_1^{[1]}$; and into the second perceptron with weights $W_2^{[1]}=\begin{bmatrix}w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$, bias $b_2^{[1]}$. The integer in the square brackets $^{[1]}$ denotes the layer number, because there are two layers now with their own parameters and outputs, which need to be distinguished.
#
# \begin{align}
# z_1^{[1](i)} &= w_{1,1}^{[1]} x_1^{(i)} + w_{2,1}^{[1]} x_2^{(i)} + b_1^{[1]} = W_1^{[1]}x^{(i)} + b_1^{[1]},\\
# z_2^{[1](i)} &= w_{1,2}^{[1]} x_1^{(i)} + w_{2,2}^{[1]} x_2^{(i)} + b_2^{[1]} = W_2^{[1]}x^{(i)} + b_2^{[1]}.\tag{1}
# \end{align}
#
# These expressions for one training example $x^{(i)}$ can be rewritten in a matrix form :
#
# $$z^{[1](i)} = W^{[1]} x^{(i)} + b^{[1]},\tag{2}$$
#
# where
#
# &emsp; &emsp; $z^{[1](i)} = \begin{bmatrix}z_1^{[1](i)} \\ z_2^{[1](i)}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$;
#
# &emsp; &emsp; $W^{[1]} = \begin{bmatrix}W_1^{[1]} \\ W_2^{[1]}\end{bmatrix} =
# \begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]} \\ w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$ is matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$;
#
# &emsp; &emsp; $b^{[1]} = \begin{bmatrix}b_1^{[1]} \\ b_2^{[1]}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$.

# %% [markdown]
# Next, the hidden layer activation function needs to be applied for each of the elements in the vector $z^{[1](i)}$. Various activation functions can be used here and in this model you will take the sigmoid function $\sigma\left(x\right) = \frac{1}{1 + e^{-x}}$. Remember that its derivative is $\frac{d\sigma}{dx} = \sigma\left(x\right)\left(1-\sigma\left(x\right)\right)$. The output of the hidden layer is a vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$:
#
# $$a^{[1](i)} = \sigma\left(z^{[1](i)}\right) =
# \begin{bmatrix}\sigma\left(z_1^{[1](i)}\right) \\ \sigma\left(z_2^{[1](i)}\right)\end{bmatrix}.\tag{3}$$
#
# Then the hidden layer output gets fed into the output layer of size $n_y = 1$. This was covered in the previous lab, the only difference are: $a^{[1](i)}$ is taken instead of $x^{(i)}$ and layer notation $^{[2]}$ appears to identify all parameters and outputs:
#
# $$z^{[2](i)} = w_1^{[2]} a_1^{[1](i)} + w_2^{[2]} a_2^{[1](i)} + b^{[2]}= W^{[2]} a^{[1](i)} + b^{[2]},\tag{4}$$
#
# &emsp; &emsp; $z^{[2](i)}$ and $b^{[2]}$ are scalars for this model, as $\left(n_y \times 1\right) = \left(1 \times 1\right)$;
#
# &emsp; &emsp; $W^{[2]} = \begin{bmatrix}w_1^{[2]} & w_2^{[2]}\end{bmatrix}$ is vector of size $\left(n_y \times n_h\right) = \left(1 \times 2\right)$.
#
# Finally, the same sigmoid function is used as the output layer activation function:
#
# $$a^{[2](i)} = \sigma\left(z^{[2](i)}\right).\tag{5}$$
#
# Mathematically the two layer neural network model for each training example $x^{(i)}$ can be written with the expressions $(2) - (5)$. Let's rewrite them next to each other for convenience:
#
# \begin{align}
# z^{[1](i)} &= W^{[1]} x^{(i)} + b^{[1]},\\
# a^{[1](i)} &= \sigma\left(z^{[1](i)}\right),\\
# z^{[2](i)} &= W^{[2]} a^{[1](i)} + b^{[2]},\\
# a^{[2](i)} &= \sigma\left(z^{[2](i)}\right).\\
# \tag{6}
# \end{align}
#
# Note, that all of the parameters to be trained in the model are without $^{(i)}$ index - they are independent on the input data.

# %% [markdown]
# Finally, the predictions for some example $x^{(i)}$ can be made taking the output $a^{[2](i)}$ and calculating $\hat{y}$ as: $\hat{y} = \begin{cases} 1 & \mbox{if } a^{[2](i)} > 0.5, \\ 0 & \mbox{otherwise }. \end{cases}$.

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Neural Network Model with Two Layers for Multiple Training Examples

# %% [markdown]
# Similarly to the single perceptron model, $m$ training examples can be organised in a matrix $X$ of a shape ($2 \times m$), putting $x^{(i)}$ into columns. Then the model $(6)$ can be rewritten in terms of matrix multiplications:
#
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right),\\
# \tag{7}
# \end{align}
#
# where $b^{[1]}$ is broadcasted to the matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$ and $b^{[2]}$ to the vector of size $\left(n_y \times m\right) = \left(1 \times m\right)$. It would be a good exercise for you to have a look at the expressions $(7)$ and check that sizes of the matrices will actually match to perform required multiplications.
#
# You have derived expressions to perform forward propagation. Time to evaluate your model and train it.

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Cost Function and Training

# %% [markdown]
# For the evaluation of this simple neural network you can use the same cost function as for the single perceptron case - log loss function. Originally initialized weights were just some random values, now you need to perform training of the model: find such set of parameters $W^{[1]}$, $b^{[1]}$, $W^{[2]}$, $b^{[2]}$, that will minimize the cost function.
#
# Like in the previous example of a single perceptron neural network, the cost function can be written as:
#
# $$\mathcal{L}\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) = \frac{1}{m}\sum_{i=1}^{m} L\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) =  \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{[2](i)}\right) - (1-y^{(i)})\log\left(1- a^{[2](i)}\right)  \large  \right), \small\tag{8}$$
#
# where $y^{(i)} \in \{0,1\}$ are the original labels and $a^{[2](i)}$ are the continuous output values of the forward propagation step (elements of array $A^{[2]}$).
#
# To minimize it, you can use gradient descent, updating the parameters with the following expressions:
#
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} },\\
# \tag{9}
# \end{align}
#
# where $\alpha$ is the learning rate.

# %% [markdown]
# To perform training of the model you need to calculate now $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial W^{[2]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[2]}}$.
#
# Let's start from the end of the neural network. You can rewrite here the corresponding expressions for $\frac{\partial \mathcal{L} }{ \partial W }$ and $\frac{\partial \mathcal{L} }{ \partial b }$ from the single perceptron neural network:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W } &=
# \frac{1}{m}\left(A-Y\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b } &=
# \frac{1}{m}\left(A-Y\right)\mathbf{1},\\
# \end{align}
#
# where $\mathbf{1}$ is just a ($m \times 1$) vector of ones. Your one perceptron is in the second layer now, so $W$ will be exchanged with $W^{[2]}$, $b$ with $b^{[2]}$, $A$ with $A^{[2]}$, $X$ with $A^{[1]}$:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1}.\\
# \tag{10}
# \end{align}

# %% [markdown]
# Let's now find $\frac{\partial \mathcal{L} }{ \partial W^{[1]}} =
# \begin{bmatrix}
# \frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\
# \frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$. It was shown in the videos that $$\frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}}=\frac{1}{m}\sum_{i=1}^{m} \left(
# \left(a^{[2](i)} - y^{(i)}\right)
# w_1^{[2]}
# \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right)\tag{11}$$
#
# If you do this accurately for each of the elements $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, you will get the following matrix:
#
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \begin{bmatrix}
# \frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\
# \frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$$
# $$= \frac{1}{m}\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}\tag{12}$$

# %% [markdown]
# Looking at this, you can notice that all terms and indices somehow are very consistent, so it all can be unified into a matrix form. And that's true! $\left(W^{[2]}\right)^T = \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}$ of size $\left(n_h \times n_y\right) = \left(2 \times 1\right)$ can be multiplied with the vector $A^{[2]} - Y$ of size $\left(n_y \times m\right) = \left(1 \times m\right)$, resulting in a matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$:
#
# $$\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)=
# \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}
# \begin{bmatrix}\left(a^{[2](1)} - y^{(1)}\right) &  \cdots & \left(a^{[2](m)} - y^{(m)}\right)\end{bmatrix}
# =\begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]} \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \end{bmatrix}$$.
#
# Now taking matrix $A^{[1]}$ of the same size $\left(n_h \times m\right) = \left(2 \times m\right)$,
#
# $$A^{[1]}
# =\begin{bmatrix}
# a_1^{[1](1)} & \cdots & a_1^{[1](m)} \\
# a_2^{[1](1)} & \cdots & a_2^{[1](m)} \end{bmatrix},$$
#
# you can calculate:
#
# $$A^{[1]}\cdot\left(1-A^{[1]}\right)
# =\begin{bmatrix}
# a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right) & \cdots & a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right) \\
# a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right) & \cdots & a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right) \end{bmatrix},$$
#
# where "$\cdot$" denotes **element by element** multiplication.

# %% [markdown]
# With the element by element multiplication,
#
# $$\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)=\begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}.$$
#
# If you perform matrix multiplication with $X^T$ of size $\left(m \times n_x\right) = \left(m \times 2\right)$, you will get matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$:
#
# $$\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T =
# \begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}
# \begin{bmatrix}
# x_1^{(1)} & x_2^{(1)} \\
# \cdots & \cdots \\
# x_1^{(m)} & x_2^{(m)}
# \end{bmatrix}$$
# $$=\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1 - a_1^{[1](i)}\right) \right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}$$
#
# This is exactly like in the expression $(12)$! So, $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$ can be written as a mixture of multiplications:
#
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T\tag{13},$$
#
# where "$\cdot$" denotes element by element multiplications.

# %% [markdown]
# Vector $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$ can be found very similarly, but the last terms in the chain rule will be equal to $1$, i.e. $\frac{\partial z_1^{[1](i)}}{ \partial b_1^{[1]}} = 1$. Thus,
#
# $$\frac{\partial \mathcal{L} }{ \partial b^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\tag{14}$$
#
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.
#
# Expressions $(10)$, $(13)$ and $(14)$ can be used for the parameters update $(9)$ performing backward propagation:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\\
# \tag{15}
# \end{align}
#
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.

# %% [markdown]
# So, to understand deeply and properly how neural networks perform and get trained, **you do need knowledge of linear algebra and calculus joined together**! But do not worry! All together it is not that scary if you do it step by step accurately with understanding of maths.
#
# Time to implement this all in the code!

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Dataset
#
# First, let's get the dataset you will work on. The following code will create $m=2000$ data points $(x_1, x_2)$ and save them in the `NumPy` array `X` of a shape $(2 \times m)$ (in the columns of the array). The labels ($0$: blue, $1$: red) will be saved in the `NumPy` array `Y` of a shape $(1 \times m)$.

# %%
m = 2000
samples, labels = make_blobs(n_samples=m, 
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]), 
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0) | (labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 0
X = np.transpose(samples)
Y = labels.reshape((1, m))

plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

print ('The shape of X is: ' + str(X.shape))
print ('The shape of Y is: ' + str(Y.shape))
print ('I have m = %d training examples!' % (m))
# Out:
# The shape of X is: (2, 2000)
# The shape of Y is: (1, 2000)
# I have m = 2000 training examples!

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Define Activation Function

# %% [markdown]
# <a name='ex01'></a>
# ### Exercise 1
#
# Define sigmoid activation function $\sigma\left(z\right) =\frac{1}{1+e^{-z}} $.

# %%
def sigmoid(z):
    ### START CODE HERE ### (~ 1 line of code)
    res = 1/(1+np.exp(-z))
    ### END CODE HERE ###
    
    return res

# %%
print("sigmoid(-2) = " + str(sigmoid(-2)))
print("sigmoid(0) = " + str(sigmoid(0)))
print("sigmoid(3.5) = " + str(sigmoid(3.5)))
# Out:
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436

# %% [markdown]
# ##### __Expected Output__
#
# Note: the values may vary in the last decimal places.
#
# ```Python
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436
# ```

# %%
w3_unittest.test_sigmoid(sigmoid)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3'></a>
# ## 3 - Implementation of the Neural Network Model with Two Layers

# %% [markdown]
# <a name='3.1'></a>
# ### 3.1 - Defining the Neural Network Structure

# %% [markdown]
# <a name='ex02'></a>
# ### Exercise 2
#
# Define three variables:
# - `n_x`: the size of the input layer
# - `n_h`: the size of the hidden layer (set it equal to 2 for now)
# - `n_y`: the size of the output layer

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hint</b></font>
# </summary>
# <p>
# <ul>
#     Use shapes of X and Y to find n_x and n_y:
#     <li>the size of the input layer n_x equals to the size of the input vectors placed in the columns of the array X,</li>
#     <li>the outpus for each of the data point will be saved in the columns of the the array Y.</li>
# </ul>
# </p>

# %%
# GRADED FUNCTION: layer_sizes

def layer_sizes(X, Y):
    """
    Arguments:
    X -- input dataset of shape (input size, number of examples)
    Y -- labels of shape (output size, number of examples)
    
    Returns:
    n_x -- the size of the input layer
    n_h -- the size of the hidden layer
    n_y -- the size of the output layer
    """
    ### START CODE HERE ### (~ 3 lines of code)
    # Size of input layer.
    n_x = X.shape[0]
    # Size of hidden layer.
    n_h = 2
    # Size of output layer.
    n_y = Y.shape[0] 
    ### END CODE HERE ###
    return (n_x, n_h, n_y)

# %%
(n_x, n_h, n_y) = layer_sizes(X, Y)
print("The size of the input layer is: n_x = " + str(n_x))
print("The size of the hidden layer is: n_h = " + str(n_h))
print("The size of the output layer is: n_y = " + str(n_y))
# Out:
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1

# %% [markdown]
# ##### __Expected Output__
#
# ```Python
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1
# ```

# %%
w3_unittest.test_layer_sizes(layer_sizes)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.2'></a>
# ### 3.2 - Initialize the Model's Parameters

# %% [markdown]
# <a name='ex03'></a>
# ### Exercise 3
#
# Implement the function `initialize_parameters()`.
#
# **Instructions**:
# - Make sure your parameters' sizes are right. Refer to the neural network figure above if needed.
# - You will initialize the weights matrix with random values.
#     - Use: `np.random.randn(a,b) * 0.01` to randomly initialize a matrix of shape (a,b).
# - You will initialize the bias vector as zeros.
#     - Use: `np.zeros((a,b))` to initialize a matrix of shape (a,b) with zeros.

# %%
# GRADED FUNCTION: initialize_parameters

def initialize_parameters(n_x, n_h, n_y):
    """
    Argument:
    n_x -- size of the input layer
    n_h -- size of the hidden layer
    n_y -- size of the output layer
    
    Returns:
    params -- python dictionary containing your parameters:
                    W1 -- weight matrix of shape (n_h, n_x)
                    b1 -- bias vector of shape (n_h, 1)
                    W2 -- weight matrix of shape (n_y, n_h)
                    b2 -- bias vector of shape (n_y, 1)
    """
    
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = np.random.randn(n_h, n_x) * 0.01
    b1 = np.zeros((n_h, 1))
    W2 = np.random.randn(n_y, n_h) * 0.01
    b2 = np.zeros((n_y, 1))
    ### END CODE HERE ###
    
    assert (W1.shape == (n_h, n_x))
    assert (b1.shape == (n_h, 1))
    assert (W2.shape == (n_y, n_h))
    assert (b2.shape == (n_y, 1))
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters = initialize_parameters(n_x, n_h, n_y)

print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
# Out:
# W1 = [[-0.00277388 -0.00354759]
#  [-0.00082741 -0.00627001]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.00043818 -0.00477218]]
# b2 = [[0.]]

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the arrays W1 and W2 maybe be different due to random initialization. You can try to restart the kernel to get the same values.
#
# ```Python
# W1 = [[ 0.01788628  0.0043651 ]
#  [ 0.00096497 -0.01863493]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.00277388 -0.00354759]]
# b2 = [[0.]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_initialize_parameters(initialize_parameters)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.3'></a>
# ### 3.3 - The Loop

# %% [markdown]
# <a name='ex04'></a>
# ### Exercise 4
#
# Implement `forward_propagation()`.
#
# **Instructions**:
# - Look above at the mathematical representation $(7)$ of your classifier (section [2.2](#2.2)):
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right).\\
# \end{align}
# - The steps you have to implement are:
#     1. Retrieve each parameter from the dictionary "parameters" (which is the output of `initialize_parameters()`) by using `parameters[".."]`.
#     2. Implement Forward Propagation. Compute `Z1` multiplying matrices `W1`, `X` and adding vector `b1`. Then find `A1` using the `sigmoid` activation function. Perform similar computations for `Z2` and `A2`.

# %%
# GRADED FUNCTION: forward_propagation

def forward_propagation(X, parameters):
    """
    Argument:
    X -- input data of size (n_x, m)
    parameters -- python dictionary containing your parameters (output of initialization function)
    
    Returns:
    A2 -- the sigmoid output of the second activation
    cache -- python dictionary containing Z1, A1, Z2, A2 
    (that simplifies the calculations in the back propagation step)
    """
    # Retrieve each parameter from the dictionary "parameters".
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]
    ### END CODE HERE ###
    
    # Implement forward propagation to calculate A2.
    ### START CODE HERE ### (~ 4 lines of code)
    Z1 = np.dot(W1, X) + b1
    A1 = sigmoid(Z1)
    Z2 = np.dot(W2, A1) + b2
    A2 = sigmoid(Z2)
    ### END CODE HERE ###
    
    assert(A2.shape == (n_y, X.shape[1]))

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %%
A2, cache = forward_propagation(X, parameters)

print(A2)
# Out:
# [[0.49935621 0.49937116 0.49936637 ... 0.49935407 0.499357   0.49936457]]

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the array A2 maybe be different depending on the initial parameters. If you would like to get exactly the same output, try to restart the Kernel and rerun the notebook.
#
# ```Python
# [[0.49920157 0.49922234 0.49921223 ... 0.49921215 0.49921043 0.49920665]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_forward_propagation(forward_propagation)
# Out:
# Test case "change_weights_check". Wrong output of Z1 for X =
# [[ 5.46584646  6.71120407  7.21301753 ...  1.77559174  3.52245562
#    7.86492998]
#  [ 2.91868287 10.31812597  7.79616824 ...  2.43434264  3.64044705
#    6.77517917]]
# Test for i = 1, j = 1999.
# 	Expected:
# -0.03577862954823146
# 	Got:
# -0.03577862954823145
#  47  Tests passed
#  1  Tests failed

# %% [markdown]
# Remember, that your weights were just initialized with some random values, so the model has not been trained yet.

# %% [markdown]
# <a name='ex05'></a>
# ### Exercise 5
#
# Define a cost function $(8)$ which will be used to train the model:
#
# $$\mathcal{L}\left(W, b\right)  = \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{(i)}\right) - (1-y^{(i)})\log\left(1- a^{(i)}\right)  \large  \right) \small.$$

# %%
def compute_cost(A2, Y):
    """
    Computes the cost function as a log loss
    
    Arguments:
    A2 -- The output of the neural network of shape (1, number of examples)
    Y -- "true" labels vector of shape (1, number of examples)
    
    Returns:
    cost -- log loss
    
    """
    # Number of examples.
    m = Y.shape[1]
    
    ### START CODE HERE ### (~ 2 lines of code)
    logloss = np.multiply(Y, np.log(A2)) + np.multiply(1-Y, np.log(1-A2))
    cost = -1/m * np.sum(logloss)
    ### END CODE HERE ###

    assert(isinstance(cost, float))
    
    return cost

# %%
print("cost = " + str(compute_cost(A2, Y)))
# Out:
# cost = 0.693147848379887

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the arrays W1 and W2 maybe be different!
#
# ```Python
# cost = 0.6931477703826823
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_compute_cost(compute_cost, A2)
# Out:
#  All tests passed

# %% [markdown]
# Calculate partial derivatives as shown in $(15)$:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1}.\\
# \end{align}

# %%
def backward_propagation(parameters, cache, X, Y):
    """
    Implements the backward propagation, calculating gradients
    
    Arguments:
    parameters -- python dictionary containing our parameters 
    cache -- python dictionary containing Z1, A1, Z2, A2
    X -- input data of shape (n_x, number of examples)
    Y -- "true" labels vector of shape (n_y, number of examples)
    
    Returns:
    grads -- python dictionary containing gradients with respect to different parameters
    """
    m = X.shape[1]
    
    # First, retrieve W from the dictionary "parameters".
    W1 = parameters["W1"]
    W2 = parameters["W2"]
    
    # Retrieve also A1 and A2 from dictionary "cache".
    A1 = cache["A1"]
    A2 = cache["A2"]
    
    # Backward propagation: calculate partial derivatives denoted as dW1, db1, dW2, db2 for simplicity. 
    dZ2 = A2 - Y
    dW2 = 1/m * np.dot(dZ2, A1.T)
    db2 = 1/m * np.sum(dZ2, axis = 1, keepdims = True)
    dZ1 = np.dot(W2.T, dZ2) * A1 * (1 - A1)
    dW1 = 1/m * np.dot(dZ1, X.T)
    db1 = 1/m * np.sum(dZ1, axis = 1, keepdims = True)
    
    grads = {"dW1": dW1,
             "db1": db1,
             "dW2": dW2,
             "db2": db2}
    
    return grads

grads = backward_propagation(parameters, cache, X, Y)

print("dW1 = " + str(grads["dW1"]))
print("db1 = " + str(grads["db1"]))
print("dW2 = " + str(grads["dW2"]))
print("db2 = " + str(grads["db2"]))
# Out:
# dW1 = [[-2.44209183e-06  2.88871905e-06]
#  [-2.68086263e-05  3.15868436e-05]]
# db1 = [[6.85195454e-08]
#  [7.51167104e-07]]
# dW2 = [[-0.00031145 -0.00028258]]
# db2 = [[-0.00063919]]

# %% [markdown]
# <a name='ex06'></a>
# ### Exercise 6
#
# Implement `update_parameters()`.
#
# **Instructions**:
# - Update parameters as shown in $(9)$ (section [2.3](#2.3)):
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} }.\\
# \end{align}
# - The steps you have to implement are:
#     1. Retrieve each parameter from the dictionary "parameters" (which is the output of `initialize_parameters()`) by using `parameters[".."]`.
#     2. Retrieve each derivative from the dictionary "grads" (which is the output of `backward_propagation()`) by using `grads[".."]`.
#     3. Update parameters.

# %%
def update_parameters(parameters, grads, learning_rate=1.2):
    """
    Updates parameters using the gradient descent update rule
    
    Arguments:
    parameters -- python dictionary containing parameters 
    grads -- python dictionary containing gradients
    learning_rate -- learning rate for gradient descent
    
    Returns:
    parameters -- python dictionary containing updated parameters 
    """
     # Retrieve each parameter from the dictionary "parameters".
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]
    ### END CODE HERE ###
    
    # Retrieve each gradient from the dictionary "grads".
    ### START CODE HERE ### (~ 4 lines of code)
    dW1 = grads["dW1"]
    db1 = grads["db1"]
    dW2 = grads["dW2"]
    db2 = grads["db2"]
    ### END CODE HERE ###
    
    # Update rule for each parameter.
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = W1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    W2 = W2 - learning_rate * dW2
    b2 = b2 - learning_rate * db2
    ### END CODE HERE ###
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters_updated = update_parameters(parameters, grads)

print("W1 updated = " + str(parameters_updated["W1"]))
print("b1 updated = " + str(parameters_updated["b1"]))
print("W2 updated = " + str(parameters_updated["W2"]))
print("b2 updated = " + str(parameters_updated["b2"]))
# Out:
# W1 updated = [[-0.00277095 -0.00355106]
#  [-0.00079524 -0.00630791]]
# b1 updated = [[-8.22234544e-08]
#  [-9.01400524e-07]]
# W2 updated = [[-6.44370575e-05 -4.43307893e-03]]
# b2 updated = [[0.00076703]]

# %% [markdown]
# ##### __Expected Output__
# Note: the actual values can be different!
#
# ```Python
# W1 updated = [[ 0.01790427  0.00434496]
#  [ 0.00099046 -0.01866419]]
# b1 updated = [[-6.13449205e-07]
#  [-8.47483463e-07]]
# W2 updated = [[-0.00238219 -0.00323487]]
# b2 updated = [[0.00094478]]
# ```

# %%
w3_unittest.test_update_parameters(update_parameters)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.4'></a>
# ### 3.4 - Integrate parts 3.1, 3.2 and 3.3 in nn_model()

# %% [markdown]
# <a name='ex07'></a>
# ### Exercise 7
#
# Build your neural network model in `nn_model()`.
#
# **Instructions**: The neural network model has to use the previous functions in the right order.

# %%
# GRADED FUNCTION: nn_model

def nn_model(X, Y, n_h, num_iterations=10, learning_rate=1.2, print_cost=False):
    """
    Arguments:
    X -- dataset of shape (n_x, number of examples)
    Y -- labels of shape (n_y, number of examples)
    num_iterations -- number of iterations in the loop
    learning_rate -- learning rate parameter for gradient descent
    print_cost -- if True, print the cost every iteration
    
    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """
    
    n_x = layer_sizes(X, Y)[0]
    n_y = layer_sizes(X, Y)[2]
    
     # Initialize parameters.
    ### START CODE HERE ### (~ 1 line of code)
    parameters = initialize_parameters(n_x, n_h, n_y)
    ### END CODE HERE ###
    
    # Loop.
    for i in range(0, num_iterations):
         
        ### START CODE HERE ### (~ 4 lines of code)
        # Forward propagation. Inputs: "X, parameters". Outputs: "A2, cache".
        A2, cache = forward_propagation(X, parameters)
        
        # Cost function. Inputs: "A2, Y". Outputs: "cost".
        cost = compute_cost(A2, Y)
        
        # Backpropagation. Inputs: "parameters, cache, X, Y". Outputs: "grads".
        grads = backward_propagation(parameters, cache, X, Y)
        
        # Gradient descent parameter update. Inputs: "parameters, grads, learning_rate". Outputs: "parameters".
        parameters = update_parameters(parameters, grads, learning_rate)
        ### END CODE HERE ###
        
        # Print the cost every iteration.
        if print_cost:
            print ("Cost after iteration %i: %f" %(i, cost))

    return parameters

# %%
parameters = nn_model(X, Y, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=True)
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))

W1 = parameters["W1"]
b1 = parameters["b1"]
W2 = parameters["W2"]
b2 = parameters["b2"]
# Out:
# Cost after iteration 0: 0.693151
# Cost after iteration 1: 0.693149
# Cost after iteration 2: 0.693148
# Cost after iteration 3: 0.693147
# Cost after iteration 4: 0.693147
# Cost after iteration 5: 0.693147
# Cost after iteration 6: 0.693147
# Cost after iteration 7: 0.693147
# Cost after iteration 8: 0.693147
# Cost after iteration 9: 0.693147
# Cost after iteration 10: 0.693147
# Cost after iteration 11: 0.693147
# Cost after iteration 12: 0.693147
# Cost after iteration 13: 0.693147
# Cost after iteration 14: 0.693147
# Cost after iteration 15: 0.693147
# Cost after iteration 16: 0.693147
# Cost after iteration 17: 0.693147
# Cost after iteration 18: 0.693147
# Cost after iteration 19: 0.693147
# Cost after iteration 20: 0.693147
# Cost after iteration 21: 0.693147
# Cost after iteration 22: 0.693147
# Cost after iteration 23: 0.693147
# Cost after iteration 24: 0.693147
# Cost after iteration 25: 0.693147
# Cost after iteration 26: 0.693147
# Cost after iteration 27: 0.693147
# Cost after iteration 28: 0.693147
# Cost after iteration 29: 0.693147
# Cost after iteration 30: 0.693147
# Cost after iteration 31: 0.693147
# Cost after iteration 32: 0.693147
# Cost after iteration 33: 0.693147
# Cost after iteration 34: 0.693146
# Cost after iteration 35: 0.693146
# Cost after iteration 36: 0.693146
# Cost after iteration 37: 0.693146
# Cost after iteration 38: 0.693146
# Cost after iteration 39: 0.693146
# Cost after iteration 40: 0.693146
# Cost after iteration 41: 0.693146
# Cost after iteration 42: 0.693146
# Cost after iteration 43: 0.693146
# Cost after iteration 44: 0.693146
# Cost after iteration 45: 0.693146
# Cost after iteration 46: 0.693146
# Cost after iteration 47: 0.693146
# Cost after iteration 48: 0.693146
# Cost after iteration 49: 0.693146
# Cost after iteration 50: 0.693146
# Cost after iteration 51: 0.693146
# Cost after iteration 52: 0.693146
# Cost after iteration 53: 0.693146
# Cost after iteration 54: 0.693146
# Cost after iteration 55: 0.693146
# Cost after iteration 56: 0.693146
# Cost after iteration 57: 0.693146
# Cost after iteration 58: 0.693146
# Cost after iteration 59: 0.693146
# Cost after iteration 60: 0.693146
# Cost after iteration 61: 0.693146
# Cost after iteration 62: 0.693145
# Cost after iteration 63: 0.693145
# Cost after iteration 64: 0.693145
# Cost after iteration 65: 0.693145
# Cost after iteration 66: 0.693145
# Cost after iteration 67: 0.693145
# Cost after iteration 68: 0.693145
# Cost after iteration 69: 0.693145
# Cost after iteration 70: 0.693145
# Cost after iteration 71: 0.693145
# Cost after iteration 72: 0.693145
# Cost after iteration 73: 0.693145
# Cost after iteration 74: 0.693145
# Cost after iteration 75: 0.693145
# Cost after iteration 76: 0.693145
# Cost after iteration 77: 0.693145
# Cost after iteration 78: 0.693145
# Cost after iteration 79: 0.693145
# Cost after iteration 80: 0.693145
# Cost after iteration 81: 0.693144
# Cost after iteration 82: 0.693144
# Cost after iteration 83: 0.693144
# Cost after iteration 84: 0.693144
# Cost after iteration 85: 0.693144
# Cost after iteration 86: 0.693144
# Cost after iteration 87: 0.693144
# Cost after iteration 88: 0.693144
# Cost after iteration 89: 0.693144
# Cost after iteration 90: 0.693144
# Cost after iteration 91: 0.693144
# Cost after iteration 92: 0.693144
# Cost after iteration 93: 0.693144
# Cost after iteration 94: 0.693144
# Cost after iteration 95: 0.693144
# Cost after iteration 96: 0.693143
# Cost after iteration 97: 0.693143
# Cost after iteration 98: 0.693143
# Cost after iteration 99: 0.693143
# Cost after iteration 100: 0.693143
# Cost after iteration 101: 0.693143
# Cost after iteration 102: 0.693143
# Cost after iteration 103: 0.693143
# Cost after iteration 104: 0.693143
# Cost after iteration 105: 0.693143
# Cost after iteration 106: 0.693143
# Cost after iteration 107: 0.693143
# Cost after iteration 108: 0.693142
# Cost after iteration 109: 0.693142
# Cost after iteration 110: 0.693142
# Cost after iteration 111: 0.693142
# Cost after iteration 112: 0.693142
# Cost after iteration 113: 0.693142
# Cost after iteration 114: 0.693142
# Cost after iteration 115: 0.693142
# Cost after iteration 116: 0.693142
# Cost after iteration 117: 0.693142
# Cost after iteration 118: 0.693141
# Cost after iteration 119: 0.693141
# Cost after iteration 120: 0.693141
# Cost after iteration 121: 0.693141
# Cost after iteration 122: 0.693141
# Cost after iteration 123: 0.693141
# Cost after iteration 124: 0.693141
# Cost after iteration 125: 0.693141
# Cost after iteration 126: 0.693140
# Cost after iteration 127: 0.693140
# Cost after iteration 128: 0.693140
# Cost after iteration 129: 0.693140
# Cost after iteration 130: 0.693140
# Cost after iteration 131: 0.693140
# Cost after iteration 132: 0.693140
# Cost after iteration 133: 0.693139
# Cost after iteration 134: 0.693139
# Cost after iteration 135: 0.693139
# Cost after iteration 136: 0.693139
# Cost after iteration 137: 0.693139
# Cost after iteration 138: 0.693139
# Cost after iteration 139: 0.693139
# Cost after iteration 140: 0.693138
# Cost after iteration 141: 0.693138
# Cost after iteration 142: 0.693138
# Cost after iteration 143: 0.693138
# Cost after iteration 144: 0.693138
# Cost after iteration 145: 0.693138
# Cost after iteration 146: 0.693137
# Cost after iteration 147: 0.693137
# Cost after iteration 148: 0.693137
# Cost after iteration 149: 0.693137
# Cost after iteration 150: 0.693137
# Cost after iteration 151: 0.693136
# Cost after iteration 152: 0.693136
# Cost after iteration 153: 0.693136
# Cost after iteration 154: 0.693136
# Cost after iteration 155: 0.693136
# Cost after iteration 156: 0.693135
# Cost after iteration 157: 0.693135
# Cost after iteration 158: 0.693135
# Cost after iteration 159: 0.693135
# Cost after iteration 160: 0.693134
# Cost after iteration 161: 0.693134
# Cost after iteration 162: 0.693134
# Cost after iteration 163: 0.693134
# Cost after iteration 164: 0.693133
# Cost after iteration 165: 0.693133
# Cost after iteration 166: 0.693133
# Cost after iteration 167: 0.693133
# Cost after iteration 168: 0.693132
# Cost after iteration 169: 0.693132
# Cost after iteration 170: 0.693132
# Cost after iteration 171: 0.693132
# Cost after iteration 172: 0.693131
# Cost after iteration 173: 0.693131
# Cost after iteration 174: 0.693131
# Cost after iteration 175: 0.693130
# Cost after iteration 176: 0.693130
# Cost after iteration 177: 0.693130
# Cost after iteration 178: 0.693129
# Cost after iteration 179: 0.693129
# Cost after iteration 180: 0.693129
# Cost after iteration 181: 0.693128
# Cost after iteration 182: 0.693128
# Cost after iteration 183: 0.693128
# Cost after iteration 184: 0.693127
# Cost after iteration 185: 0.693127
# Cost after iteration 186: 0.693127
# Cost after iteration 187: 0.693126
# Cost after iteration 188: 0.693126
# Cost after iteration 189: 0.693125
# Cost after iteration 190: 0.693125
# Cost after iteration 191: 0.693125
# Cost after iteration 192: 0.693124
# Cost after iteration 193: 0.693124
# Cost after iteration 194: 0.693123
# Cost after iteration 195: 0.693123
# Cost after iteration 196: 0.693122
# Cost after iteration 197: 0.693122
# Cost after iteration 198: 0.693121
# Cost after iteration 199: 0.693121
# Cost after iteration 200: 0.693120
# Cost after iteration 201: 0.693120
# Cost after iteration 202: 0.693119
# Cost after iteration 203: 0.693119
# Cost after iteration 204: 0.693118
# Cost after iteration 205: 0.693118
# Cost after iteration 206: 0.693117
# Cost after iteration 207: 0.693117
# Cost after iteration 208: 0.693116
# Cost after iteration 209: 0.693115
# Cost after iteration 210: 0.693115
# Cost after iteration 211: 0.693114
# Cost after iteration 212: 0.693114
# Cost after iteration 213: 0.693113
# Cost after iteration 214: 0.693112
# Cost after iteration 215: 0.693112
# Cost after iteration 216: 0.693111
# Cost after iteration 217: 0.693110
# Cost after iteration 218: 0.693109
# Cost after iteration 219: 0.693109
# Cost after iteration 220: 0.693108
# Cost after iteration 221: 0.693107
# Cost after iteration 222: 0.693106
# Cost after iteration 223: 0.693105
# Cost after iteration 224: 0.693104
# Cost after iteration 225: 0.693104
# Cost after iteration 226: 0.693103
# Cost after iteration 227: 0.693102
# Cost after iteration 228: 0.693101
# Cost after iteration 229: 0.693100
# Cost after iteration 230: 0.693099
# Cost after iteration 231: 0.693098
# Cost after iteration 232: 0.693096
# Cost after iteration 233: 0.693095
# Cost after iteration 234: 0.693094
# Cost after iteration 235: 0.693093
# Cost after iteration 236: 0.693092
# Cost after iteration 237: 0.693090
# Cost after iteration 238: 0.693089
# Cost after iteration 239: 0.693087
# Cost after iteration 240: 0.693086
# Cost after iteration 241: 0.693085
# Cost after iteration 242: 0.693083
# Cost after iteration 243: 0.693081
# Cost after iteration 244: 0.693080
# Cost after iteration 245: 0.693078
# Cost after iteration 246: 0.693076
# Cost after iteration 247: 0.693074
# Cost after iteration 248: 0.693072
# Cost after iteration 249: 0.693070
# Cost after iteration 250: 0.693068
# Cost after iteration 251: 0.693065
# Cost after iteration 252: 0.693063
# Cost after iteration 253: 0.693060
# Cost after iteration 254: 0.693057
# Cost after iteration 255: 0.693055
# Cost after iteration 256: 0.693052
# Cost after iteration 257: 0.693048
# Cost after iteration 258: 0.693045
# Cost after iteration 259: 0.693042
# Cost after iteration 260: 0.693038
# Cost after iteration 261: 0.693034
# Cost after iteration 262: 0.693030
# Cost after iteration 263: 0.693025
# Cost after iteration 264: 0.693020
# Cost after iteration 265: 0.693015
# Cost after iteration 266: 0.693010
# Cost after iteration 267: 0.693004
# Cost after iteration 268: 0.692998
# Cost after iteration 269: 0.692991
# Cost after iteration 270: 0.692984
# Cost after iteration 271: 0.692976
# Cost after iteration 272: 0.692967
# Cost after iteration 273: 0.692958
# Cost after iteration 274: 0.692948
# Cost after iteration 275: 0.692937
# Cost after iteration 276: 0.692926
# Cost after iteration 277: 0.692913
# Cost after iteration 278: 0.692899
# Cost after iteration 279: 0.692883
# Cost after iteration 280: 0.692866
# Cost after iteration 281: 0.692847
# Cost after iteration 282: 0.692826
# Cost after iteration 283: 0.692803
# Cost after iteration 284: 0.692777
# Cost after iteration 285: 0.692748
# Cost after iteration 286: 0.692716
# Cost after iteration 287: 0.692679
# Cost after iteration 288: 0.692638
# Cost after iteration 289: 0.692591
# Cost after iteration 290: 0.692538
# Cost after iteration 291: 0.692478
# Cost after iteration 292: 0.692409
# Cost after iteration 293: 0.692330
# Cost after iteration 294: 0.692238
# Cost after iteration 295: 0.692133
# Cost after iteration 296: 0.692010
# Cost after iteration 297: 0.691868
# Cost after iteration 298: 0.691702
# Cost after iteration 299: 0.691507
# Cost after iteration 300: 0.691280
# Cost after iteration 301: 0.691013
# Cost after iteration 302: 0.690700
# Cost after iteration 303: 0.690331
# Cost after iteration 304: 0.689899
# Cost after iteration 305: 0.689392
# Cost after iteration 306: 0.688798
# Cost after iteration 307: 0.688106
# Cost after iteration 308: 0.687302
# Cost after iteration 309: 0.686373
# Cost after iteration 310: 0.685308
# Cost after iteration 311: 0.684095
# Cost after iteration 312: 0.682726
# Cost after iteration 313: 0.681195
# Cost after iteration 314: 0.679499
# Cost after iteration 315: 0.677641
# Cost after iteration 316: 0.675627
# Cost after iteration 317: 0.673466
# Cost after iteration 318: 0.671171
# Cost after iteration 319: 0.668759
# Cost after iteration 320: 0.666247
# Cost after iteration 321: 0.663655
# Cost after iteration 322: 0.661001
# Cost after iteration 323: 0.658304
# Cost after iteration 324: 0.655582
# Cost after iteration 325: 0.652851
# Cost after iteration 326: 0.650125
# Cost after iteration 327: 0.647416
# Cost after iteration 328: 0.644737
# Cost after iteration 329: 0.642094
# Cost after iteration 330: 0.639496
# Cost after iteration 331: 0.636947
# Cost after iteration 332: 0.634451
# Cost after iteration 333: 0.632010
# Cost after iteration 334: 0.629627
# Cost after iteration 335: 0.627300
# Cost after iteration 336: 0.625029
# Cost after iteration 337: 0.622812
# Cost after iteration 338: 0.620647
# Cost after iteration 339: 0.618530
# Cost after iteration 340: 0.616456
# Cost after iteration 341: 0.614419
# Cost after iteration 342: 0.612410
# Cost after iteration 343: 0.610417
# Cost after iteration 344: 0.608427
# Cost after iteration 345: 0.606418
# Cost after iteration 346: 0.604365
# Cost after iteration 347: 0.602238
# Cost after iteration 348: 0.600000
# Cost after iteration 349: 0.597611
# Cost after iteration 350: 0.595032
# Cost after iteration 351: 0.592227
# Cost after iteration 352: 0.589159
# Cost after iteration 353: 0.585793
# Cost after iteration 354: 0.582099
# Cost after iteration 355: 0.578056
# Cost after iteration 356: 0.573653
# Cost after iteration 357: 0.568893
# Cost after iteration 358: 0.563791
# Cost after iteration 359: 0.558375
# Cost after iteration 360: 0.552682
# Cost after iteration 361: 0.546756
# Cost after iteration 362: 0.540641
# Cost after iteration 363: 0.534383
# Cost after iteration 364: 0.528027
# Cost after iteration 365: 0.521612
# Cost after iteration 366: 0.515175
# Cost after iteration 367: 0.508748
# Cost after iteration 368: 0.502358
# Cost after iteration 369: 0.496029
# Cost after iteration 370: 0.489779
# Cost after iteration 371: 0.483624
# Cost after iteration 372: 0.477577
# Cost after iteration 373: 0.471648
# Cost after iteration 374: 0.465845
# Cost after iteration 375: 0.460173
# Cost after iteration 376: 0.454636
# Cost after iteration 377: 0.449236
# Cost after iteration 378: 0.443976
# Cost after iteration 379: 0.438855
# Cost after iteration 380: 0.433872
# Cost after iteration 381: 0.429028
# Cost after iteration 382: 0.424319
# Cost after iteration 383: 0.419743
# Cost after iteration 384: 0.415299
# Cost after iteration 385: 0.410983
# Cost after iteration 386: 0.406792
# Cost after iteration 387: 0.402723
# Cost after iteration 388: 0.398772
# Cost after iteration 389: 0.394937
# Cost after iteration 390: 0.391214
# Cost after iteration 391: 0.387598
# Cost after iteration 392: 0.384088
# Cost after iteration 393: 0.380679
# Cost after iteration 394: 0.377368
# Cost after iteration 395: 0.374152
# Cost after iteration 396: 0.371027
# Cost after iteration 397: 0.367991
# Cost after iteration 398: 0.365039
# Cost after iteration 399: 0.362171
# Cost after iteration 400: 0.359381
# Cost after iteration 401: 0.356668
# Cost after iteration 402: 0.354029
# Cost after iteration 403: 0.351461
# Cost after iteration 404: 0.348961
# Cost after iteration 405: 0.346527
# Cost after iteration 406: 0.344157
# Cost after iteration 407: 0.341849
# Cost after iteration 408: 0.339599
# Cost after iteration 409: 0.337406
# Cost after iteration 410: 0.335269
# Cost after iteration 411: 0.333184
# Cost after iteration 412: 0.331150
# Cost after iteration 413: 0.329166
# Cost after iteration 414: 0.327229
# Cost after iteration 415: 0.325337
# Cost after iteration 416: 0.323490
# Cost after iteration 417: 0.321686
# Cost after iteration 418: 0.319922
# Cost after iteration 419: 0.318198
# Cost after iteration 420: 0.316512
# Cost after iteration 421: 0.314863
# Cost after iteration 422: 0.313249
# Cost after iteration 423: 0.311670
# Cost after iteration 424: 0.310124
# Cost after iteration 425: 0.308610
# Cost after iteration 426: 0.307126
# Cost after iteration 427: 0.305673
# Cost after iteration 428: 0.304248
# Cost after iteration 429: 0.302852
# Cost after iteration 430: 0.301482
# Cost after iteration 431: 0.300138
# Cost after iteration 432: 0.298819
# Cost after iteration 433: 0.297525
# Cost after iteration 434: 0.296254
# Cost after iteration 435: 0.295006
# Cost after iteration 436: 0.293779
# Cost after iteration 437: 0.292574
# Cost after iteration 438: 0.291390
# Cost after iteration 439: 0.290225
# Cost after iteration 440: 0.289080
# Cost after iteration 441: 0.287954
# Cost after iteration 442: 0.286845
# Cost after iteration 443: 0.285754
# Cost after iteration 444: 0.284680
# Cost after iteration 445: 0.283623
# Cost after iteration 446: 0.282581
# Cost after iteration 447: 0.281555
# Cost after iteration 448: 0.280544
# Cost after iteration 449: 0.279547
# Cost after iteration 450: 0.278564
# Cost after iteration 451: 0.277595
# Cost after iteration 452: 0.276639
# Cost after iteration 453: 0.275697
# Cost after iteration 454: 0.274766
# Cost after iteration 455: 0.273848
# Cost after iteration 456: 0.272941
# Cost after iteration 457: 0.272046
# Cost after iteration 458: 0.271162
# Cost after iteration 459: 0.270289
# Cost after iteration 460: 0.269427
# Cost after iteration 461: 0.268575
# Cost after iteration 462: 0.267732
# Cost after iteration 463: 0.266900
# Cost after iteration 464: 0.266076
# Cost after iteration 465: 0.265262
# Cost after iteration 466: 0.264457
# Cost after iteration 467: 0.263661
# Cost after iteration 468: 0.262873
# Cost after iteration 469: 0.262093
# Cost after iteration 470: 0.261322
# Cost after iteration 471: 0.260558
# Cost after iteration 472: 0.259802
# Cost after iteration 473: 0.259054
# Cost after iteration 474: 0.258313
# Cost after iteration 475: 0.257579
# Cost after iteration 476: 0.256853
# Cost after iteration 477: 0.256133
# Cost after iteration 478: 0.255420
# Cost after iteration 479: 0.254713
# Cost after iteration 480: 0.254013
# Cost after iteration 481: 0.253320
# Cost after iteration 482: 0.252632
# Cost after iteration 483: 0.251951
# Cost after iteration 484: 0.251276
# Cost after iteration 485: 0.250606
# Cost after iteration 486: 0.249943
# Cost after iteration 487: 0.249285
# Cost after iteration 488: 0.248633
# Cost after iteration 489: 0.247986
# Cost after iteration 490: 0.247345
# Cost after iteration 491: 0.246709
# Cost after iteration 492: 0.246078
# Cost after iteration 493: 0.245453
# Cost after iteration 494: 0.244833
# Cost after iteration 495: 0.244218
# Cost after iteration 496: 0.243607
# Cost after iteration 497: 0.243002
# Cost after iteration 498: 0.242402
# Cost after iteration 499: 0.241807
# Cost after iteration 500: 0.241216
# Cost after iteration 501: 0.240631
# Cost after iteration 502: 0.240050
# Cost after iteration 503: 0.239474
# Cost after iteration 504: 0.238902
# Cost after iteration 505: 0.238335
# Cost after iteration 506: 0.237773
# Cost after iteration 507: 0.237215
# Cost after iteration 508: 0.236662
# Cost after iteration 509: 0.236114
# Cost after iteration 510: 0.235569
# Cost after iteration 511: 0.235030
# Cost after iteration 512: 0.234495
# Cost after iteration 513: 0.233964
# Cost after iteration 514: 0.233438
# Cost after iteration 515: 0.232916
# Cost after iteration 516: 0.232398
# Cost after iteration 517: 0.231885
# Cost after iteration 518: 0.231376
# Cost after iteration 519: 0.230872
# Cost after iteration 520: 0.230372
# Cost after iteration 521: 0.229876
# Cost after iteration 522: 0.229384
# Cost after iteration 523: 0.228897
# Cost after iteration 524: 0.228414
# Cost after iteration 525: 0.227935
# Cost after iteration 526: 0.227461
# Cost after iteration 527: 0.226990
# Cost after iteration 528: 0.226524
# Cost after iteration 529: 0.226063
# Cost after iteration 530: 0.225605
# Cost after iteration 531: 0.225151
# Cost after iteration 532: 0.224702
# Cost after iteration 533: 0.224257
# Cost after iteration 534: 0.223816
# Cost after iteration 535: 0.223379
# Cost after iteration 536: 0.222947
# Cost after iteration 537: 0.222518
# Cost after iteration 538: 0.222093
# Cost after iteration 539: 0.221673
# Cost after iteration 540: 0.221257
# Cost after iteration 541: 0.220844
# Cost after iteration 542: 0.220436
# Cost after iteration 543: 0.220032
# Cost after iteration 544: 0.219631
# Cost after iteration 545: 0.219235
# Cost after iteration 546: 0.218842
# Cost after iteration 547: 0.218454
# Cost after iteration 548: 0.218069
# Cost after iteration 549: 0.217688
# Cost after iteration 550: 0.217312
# Cost after iteration 551: 0.216939
# Cost after iteration 552: 0.216569
# Cost after iteration 553: 0.216204
# Cost after iteration 554: 0.215842
# Cost after iteration 555: 0.215484
# Cost after iteration 556: 0.215130
# Cost after iteration 557: 0.214779
# Cost after iteration 558: 0.214432
# Cost after iteration 559: 0.214089
# Cost after iteration 560: 0.213749
# Cost after iteration 561: 0.213413
# Cost after iteration 562: 0.213081
# Cost after iteration 563: 0.212752
# Cost after iteration 564: 0.212426
# Cost after iteration 565: 0.212104
# Cost after iteration 566: 0.211785
# Cost after iteration 567: 0.211470
# Cost after iteration 568: 0.211158
# Cost after iteration 569: 0.210849
# Cost after iteration 570: 0.210544
# Cost after iteration 571: 0.210242
# Cost after iteration 572: 0.209943
# Cost after iteration 573: 0.209648
# Cost after iteration 574: 0.209358
# Cost after iteration 575: 0.209080
# Cost after iteration 576: 0.208839
# Cost after iteration 577: 0.208743
# Cost after iteration 578: 0.209258
# Cost after iteration 579: 0.212411
# Cost after iteration 580: 0.227588
# Cost after iteration 581: 0.303399
# Cost after iteration 582: 0.643185
# Cost after iteration 583: 0.623887
# Cost after iteration 584: 1.162330
# Cost after iteration 585: 0.462390
# Cost after iteration 586: 0.536033
# Cost after iteration 587: 0.233895
# Cost after iteration 588: 0.231545
# Cost after iteration 589: 0.229493
# Cost after iteration 590: 0.227681
# Cost after iteration 591: 0.226070
# Cost after iteration 592: 0.224628
# Cost after iteration 593: 0.223332
# Cost after iteration 594: 0.222159
# Cost after iteration 595: 0.221092
# Cost after iteration 596: 0.220117
# Cost after iteration 597: 0.219221
# Cost after iteration 598: 0.218393
# Cost after iteration 599: 0.217624
# Cost after iteration 600: 0.216906
# Cost after iteration 601: 0.216232
# Cost after iteration 602: 0.215598
# Cost after iteration 603: 0.214997
# Cost after iteration 604: 0.214426
# Cost after iteration 605: 0.213881
# Cost after iteration 606: 0.213360
# Cost after iteration 607: 0.212858
# Cost after iteration 608: 0.212375
# Cost after iteration 609: 0.211908
# Cost after iteration 610: 0.211455
# Cost after iteration 611: 0.211015
# Cost after iteration 612: 0.210588
# Cost after iteration 613: 0.210171
# Cost after iteration 614: 0.209764
# Cost after iteration 615: 0.209367
# Cost after iteration 616: 0.208978
# Cost after iteration 617: 0.208597
# Cost after iteration 618: 0.208224
# Cost after iteration 619: 0.207858
# Cost after iteration 620: 0.207498
# Cost after iteration 621: 0.207146
# Cost after iteration 622: 0.206799
# Cost after iteration 623: 0.206459
# Cost after iteration 624: 0.206125
# Cost after iteration 625: 0.205797
# Cost after iteration 626: 0.205474
# Cost after iteration 627: 0.205157
# Cost after iteration 628: 0.204845
# Cost after iteration 629: 0.204538
# Cost after iteration 630: 0.204237
# Cost after iteration 631: 0.203941
# Cost after iteration 632: 0.203649
# Cost after iteration 633: 0.203363
# Cost after iteration 634: 0.203082
# Cost after iteration 635: 0.202805
# Cost after iteration 636: 0.202534
# Cost after iteration 637: 0.202267
# Cost after iteration 638: 0.202004
# Cost after iteration 639: 0.201746
# Cost after iteration 640: 0.201493
# Cost after iteration 641: 0.201244
# Cost after iteration 642: 0.200999
# Cost after iteration 643: 0.200758
# Cost after iteration 644: 0.200522
# Cost after iteration 645: 0.200290
# Cost after iteration 646: 0.200061
# Cost after iteration 647: 0.199837
# Cost after iteration 648: 0.199617
# Cost after iteration 649: 0.199400
# Cost after iteration 650: 0.199187
# Cost after iteration 651: 0.198978
# Cost after iteration 652: 0.198772
# Cost after iteration 653: 0.198570
# Cost after iteration 654: 0.198372
# Cost after iteration 655: 0.198177
# Cost after iteration 656: 0.197988
# Cost after iteration 657: 0.197809
# Cost after iteration 658: 0.197655
# Cost after iteration 659: 0.197571
# Cost after iteration 660: 0.197715
# Cost after iteration 661: 0.198602
# Cost after iteration 662: 0.202079
# Cost after iteration 663: 0.214733
# Cost after iteration 664: 0.266153
# Cost after iteration 665: 0.457080
# Cost after iteration 666: 0.834419
# Cost after iteration 667: 0.267927
# Cost after iteration 668: 0.354729
# Cost after iteration 669: 0.301797
# Cost after iteration 670: 0.383890
# Cost after iteration 671: 0.259055
# Cost after iteration 672: 0.261328
# Cost after iteration 673: 0.225420
# Cost after iteration 674: 0.222120
# Cost after iteration 675: 0.216967
# Cost after iteration 676: 0.214865
# Cost after iteration 677: 0.213287
# Cost after iteration 678: 0.212168
# Cost after iteration 679: 0.211844
# Cost after iteration 680: 0.211438
# Cost after iteration 681: 0.211953
# Cost after iteration 682: 0.212280
# Cost after iteration 683: 0.213814
# Cost after iteration 684: 0.215230
# Cost after iteration 685: 0.218489
# Cost after iteration 686: 0.221940
# Cost after iteration 687: 0.228409
# Cost after iteration 688: 0.236141
# Cost after iteration 689: 0.247736
# Cost after iteration 690: 0.264319
# Cost after iteration 691: 0.277437
# Cost after iteration 692: 0.301586
# Cost after iteration 693: 0.296056
# Cost after iteration 694: 0.301375
# Cost after iteration 695: 0.272750
# Cost after iteration 696: 0.254232
# Cost after iteration 697: 0.237252
# Cost after iteration 698: 0.226137
# Cost after iteration 699: 0.219248
# Cost after iteration 700: 0.218226
# Cost after iteration 701: 0.214396
# Cost after iteration 702: 0.215412
# Cost after iteration 703: 0.212417
# Cost after iteration 704: 0.213536
# Cost after iteration 705: 0.210948
# Cost after iteration 706: 0.211949
# Cost after iteration 707: 0.209686
# Cost after iteration 708: 0.210593
# Cost after iteration 709: 0.208606
# Cost after iteration 710: 0.209469
# Cost after iteration 711: 0.207711
# Cost after iteration 712: 0.208585
# Cost after iteration 713: 0.207012
# Cost after iteration 714: 0.207951
# Cost after iteration 715: 0.206525
# Cost after iteration 716: 0.207588
# Cost after iteration 717: 0.206275
# Cost after iteration 718: 0.207531
# Cost after iteration 719: 0.206303
# Cost after iteration 720: 0.207840
# Cost after iteration 721: 0.206675
# Cost after iteration 722: 0.208614
# Cost after iteration 723: 0.207507
# Cost after iteration 724: 0.210022
# Cost after iteration 725: 0.209007
# Cost after iteration 726: 0.212384
# Cost after iteration 727: 0.211617
# Cost after iteration 728: 0.216398
# Cost after iteration 729: 0.216443
# Cost after iteration 730: 0.223934
# Cost after iteration 731: 0.226786
# Cost after iteration 732: 0.241098
# Cost after iteration 733: 0.253851
# Cost after iteration 734: 0.292158
# Cost after iteration 735: 0.328334
# Cost after iteration 736: 0.416512
# Cost after iteration 737: 0.403633
# Cost after iteration 738: 0.409711
# Cost after iteration 739: 0.313114
# Cost after iteration 740: 0.280016
# Cost after iteration 741: 0.238569
# Cost after iteration 742: 0.225669
# Cost after iteration 743: 0.214686
# Cost after iteration 744: 0.212460
# Cost after iteration 745: 0.208273
# Cost after iteration 746: 0.206925
# Cost after iteration 747: 0.204916
# Cost after iteration 748: 0.203981
# Cost after iteration 749: 0.202898
# Cost after iteration 750: 0.202243
# Cost after iteration 751: 0.201565
# Cost after iteration 752: 0.201070
# Cost after iteration 753: 0.200576
# Cost after iteration 754: 0.200168
# Cost after iteration 755: 0.199765
# Cost after iteration 756: 0.199406
# Cost after iteration 757: 0.199053
# Cost after iteration 758: 0.198726
# Cost after iteration 759: 0.198404
# Cost after iteration 760: 0.198100
# Cost after iteration 761: 0.197800
# Cost after iteration 762: 0.197514
# Cost after iteration 763: 0.197233
# Cost after iteration 764: 0.196962
# Cost after iteration 765: 0.196696
# Cost after iteration 766: 0.196441
# Cost after iteration 767: 0.196190
# Cost after iteration 768: 0.195949
# Cost after iteration 769: 0.195713
# Cost after iteration 770: 0.195489
# Cost after iteration 771: 0.195270
# Cost after iteration 772: 0.195065
# Cost after iteration 773: 0.194865
# Cost after iteration 774: 0.194686
# Cost after iteration 775: 0.194513
# Cost after iteration 776: 0.194373
# Cost after iteration 777: 0.194241
# Cost after iteration 778: 0.194169
# Cost after iteration 779: 0.194109
# Cost after iteration 780: 0.194169
# Cost after iteration 781: 0.194249
# Cost after iteration 782: 0.194599
# Cost after iteration 783: 0.194979
# Cost after iteration 784: 0.196035
# Cost after iteration 785: 0.197114
# Cost after iteration 786: 0.200069
# Cost after iteration 787: 0.202843
# Cost after iteration 788: 0.211218
# Cost after iteration 789: 0.217317
# Cost after iteration 790: 0.239588
# Cost after iteration 791: 0.244645
# Cost after iteration 792: 0.292015
# Cost after iteration 793: 0.289401
# Cost after iteration 794: 0.385812
# Cost after iteration 795: 0.415925
# Cost after iteration 796: 0.583506
# Cost after iteration 797: 0.402359
# Cost after iteration 798: 0.380607
# Cost after iteration 799: 0.272326
# Cost after iteration 800: 0.235925
# Cost after iteration 801: 0.215650
# Cost after iteration 802: 0.208198
# Cost after iteration 803: 0.204153
# Cost after iteration 804: 0.202515
# Cost after iteration 805: 0.201270
# Cost after iteration 806: 0.200527
# Cost after iteration 807: 0.199915
# Cost after iteration 808: 0.199438
# Cost after iteration 809: 0.199011
# Cost after iteration 810: 0.198630
# Cost after iteration 811: 0.198272
# Cost after iteration 812: 0.197934
# Cost after iteration 813: 0.197610
# Cost after iteration 814: 0.197298
# Cost after iteration 815: 0.196997
# Cost after iteration 816: 0.196704
# Cost after iteration 817: 0.196419
# Cost after iteration 818: 0.196143
# Cost after iteration 819: 0.195874
# Cost after iteration 820: 0.195611
# Cost after iteration 821: 0.195356
# Cost after iteration 822: 0.195107
# Cost after iteration 823: 0.194864
# Cost after iteration 824: 0.194628
# Cost after iteration 825: 0.194397
# Cost after iteration 826: 0.194172
# Cost after iteration 827: 0.193953
# Cost after iteration 828: 0.193739
# Cost after iteration 829: 0.193530
# Cost after iteration 830: 0.193327
# Cost after iteration 831: 0.193128
# Cost after iteration 832: 0.192935
# Cost after iteration 833: 0.192746
# Cost after iteration 834: 0.192562
# Cost after iteration 835: 0.192383
# Cost after iteration 836: 0.192208
# Cost after iteration 837: 0.192038
# Cost after iteration 838: 0.191872
# Cost after iteration 839: 0.191710
# Cost after iteration 840: 0.191552
# Cost after iteration 841: 0.191398
# Cost after iteration 842: 0.191249
# Cost after iteration 843: 0.191103
# Cost after iteration 844: 0.190961
# Cost after iteration 845: 0.190823
# Cost after iteration 846: 0.190690
# Cost after iteration 847: 0.190560
# Cost after iteration 848: 0.190435
# Cost after iteration 849: 0.190316
# Cost after iteration 850: 0.190202
# Cost after iteration 851: 0.190096
# Cost after iteration 852: 0.190002
# Cost after iteration 853: 0.189922
# Cost after iteration 854: 0.189868
# Cost after iteration 855: 0.189846
# Cost after iteration 856: 0.189896
# Cost after iteration 857: 0.190031
# Cost after iteration 858: 0.190386
# Cost after iteration 859: 0.190986
# Cost after iteration 860: 0.192344
# Cost after iteration 861: 0.194450
# Cost after iteration 862: 0.199530
# Cost after iteration 863: 0.207018
# Cost after iteration 864: 0.227697
# Cost after iteration 865: 0.254208
# Cost after iteration 866: 0.347999
# Cost after iteration 867: 0.435371
# Cost after iteration 868: 0.877964
# Cost after iteration 869: 0.453747
# Cost after iteration 870: 0.514167
# Cost after iteration 871: 0.287029
# Cost after iteration 872: 0.242091
# Cost after iteration 873: 0.215575
# Cost after iteration 874: 0.205277
# Cost after iteration 875: 0.202065
# Cost after iteration 876: 0.200738
# Cost after iteration 877: 0.199990
# Cost after iteration 878: 0.199433
# Cost after iteration 879: 0.198950
# Cost after iteration 880: 0.198506
# Cost after iteration 881: 0.198087
# Cost after iteration 882: 0.197690
# Cost after iteration 883: 0.197310
# Cost after iteration 884: 0.196946
# Cost after iteration 885: 0.196598
# Cost after iteration 886: 0.196263
# Cost after iteration 887: 0.195941
# Cost after iteration 888: 0.195632
# Cost after iteration 889: 0.195335
# Cost after iteration 890: 0.195048
# Cost after iteration 891: 0.194772
# Cost after iteration 892: 0.194506
# Cost after iteration 893: 0.194249
# Cost after iteration 894: 0.194001
# Cost after iteration 895: 0.193761
# Cost after iteration 896: 0.193530
# Cost after iteration 897: 0.193306
# Cost after iteration 898: 0.193089
# Cost after iteration 899: 0.192879
# Cost after iteration 900: 0.192676
# Cost after iteration 901: 0.192480
# Cost after iteration 902: 0.192289
# Cost after iteration 903: 0.192104
# Cost after iteration 904: 0.191925
# Cost after iteration 905: 0.191751
# Cost after iteration 906: 0.191583
# Cost after iteration 907: 0.191419
# Cost after iteration 908: 0.191260
# Cost after iteration 909: 0.191106
# Cost after iteration 910: 0.190956
# Cost after iteration 911: 0.190811
# Cost after iteration 912: 0.190669
# Cost after iteration 913: 0.190532
# Cost after iteration 914: 0.190398
# Cost after iteration 915: 0.190268
# Cost after iteration 916: 0.190142
# Cost after iteration 917: 0.190019
# Cost after iteration 918: 0.189899
# Cost after iteration 919: 0.189783
# Cost after iteration 920: 0.189670
# Cost after iteration 921: 0.189559
# Cost after iteration 922: 0.189452
# Cost after iteration 923: 0.189347
# Cost after iteration 924: 0.189245
# Cost after iteration 925: 0.189146
# Cost after iteration 926: 0.189049
# Cost after iteration 927: 0.188954
# Cost after iteration 928: 0.188862
# Cost after iteration 929: 0.188773
# Cost after iteration 930: 0.188685
# Cost after iteration 931: 0.188599
# Cost after iteration 932: 0.188516
# Cost after iteration 933: 0.188435
# Cost after iteration 934: 0.188355
# Cost after iteration 935: 0.188277
# Cost after iteration 936: 0.188201
# Cost after iteration 937: 0.188127
# Cost after iteration 938: 0.188055
# Cost after iteration 939: 0.187984
# Cost after iteration 940: 0.187914
# Cost after iteration 941: 0.187847
# Cost after iteration 942: 0.187780
# Cost after iteration 943: 0.187716
# Cost after iteration 944: 0.187652
# Cost after iteration 945: 0.187590
# Cost after iteration 946: 0.187529
# Cost after iteration 947: 0.187470
# Cost after iteration 948: 0.187413
# Cost after iteration 949: 0.187359
# Cost after iteration 950: 0.187308
# Cost after iteration 951: 0.187263
# Cost after iteration 952: 0.187230
# Cost after iteration 953: 0.187219
# Cost after iteration 954: 0.187254
# Cost after iteration 955: 0.187382
# Cost after iteration 956: 0.187714
# Cost after iteration 957: 0.188450
# Cost after iteration 958: 0.190173
# Cost after iteration 959: 0.193791
# Cost after iteration 960: 0.202930
# Cost after iteration 961: 0.223044
# Cost after iteration 962: 0.290494
# Cost after iteration 963: 0.421442
# Cost after iteration 964: 0.722332
# Cost after iteration 965: 0.439385
# Cost after iteration 966: 0.735094
# Cost after iteration 967: 0.337155
# Cost after iteration 968: 0.303818
# Cost after iteration 969: 0.226322
# Cost after iteration 970: 0.209806
# Cost after iteration 971: 0.202712
# Cost after iteration 972: 0.199967
# Cost after iteration 973: 0.198530
# Cost after iteration 974: 0.197700
# Cost after iteration 975: 0.197077
# Cost after iteration 976: 0.196568
# Cost after iteration 977: 0.196117
# Cost after iteration 978: 0.195704
# Cost after iteration 979: 0.195317
# Cost after iteration 980: 0.194953
# Cost after iteration 981: 0.194608
# Cost after iteration 982: 0.194279
# Cost after iteration 983: 0.193966
# Cost after iteration 984: 0.193667
# Cost after iteration 985: 0.193381
# Cost after iteration 986: 0.193108
# Cost after iteration 987: 0.192847
# Cost after iteration 988: 0.192597
# Cost after iteration 989: 0.192357
# Cost after iteration 990: 0.192127
# Cost after iteration 991: 0.191907
# Cost after iteration 992: 0.191695
# Cost after iteration 993: 0.191492
# Cost after iteration 994: 0.191296
# Cost after iteration 995: 0.191108
# Cost after iteration 996: 0.190927
# Cost after iteration 997: 0.190753
# Cost after iteration 998: 0.190586
# Cost after iteration 999: 0.190424
# Cost after iteration 1000: 0.190269
# Cost after iteration 1001: 0.190119
# Cost after iteration 1002: 0.189974
# Cost after iteration 1003: 0.189834
# Cost after iteration 1004: 0.189699
# Cost after iteration 1005: 0.189569
# Cost after iteration 1006: 0.189443
# Cost after iteration 1007: 0.189321
# Cost after iteration 1008: 0.189203
# Cost after iteration 1009: 0.189089
# Cost after iteration 1010: 0.188978
# Cost after iteration 1011: 0.188872
# Cost after iteration 1012: 0.188768
# Cost after iteration 1013: 0.188668
# Cost after iteration 1014: 0.188571
# Cost after iteration 1015: 0.188476
# Cost after iteration 1016: 0.188385
# Cost after iteration 1017: 0.188296
# Cost after iteration 1018: 0.188210
# Cost after iteration 1019: 0.188127
# Cost after iteration 1020: 0.188045
# Cost after iteration 1021: 0.187966
# Cost after iteration 1022: 0.187890
# Cost after iteration 1023: 0.187815
# Cost after iteration 1024: 0.187743
# Cost after iteration 1025: 0.187672
# Cost after iteration 1026: 0.187603
# Cost after iteration 1027: 0.187536
# Cost after iteration 1028: 0.187471
# Cost after iteration 1029: 0.187408
# Cost after iteration 1030: 0.187346
# Cost after iteration 1031: 0.187286
# Cost after iteration 1032: 0.187228
# Cost after iteration 1033: 0.187171
# Cost after iteration 1034: 0.187116
# Cost after iteration 1035: 0.187063
# Cost after iteration 1036: 0.187012
# Cost after iteration 1037: 0.186964
# Cost after iteration 1038: 0.186920
# Cost after iteration 1039: 0.186883
# Cost after iteration 1040: 0.186857
# Cost after iteration 1041: 0.186849
# Cost after iteration 1042: 0.186875
# Cost after iteration 1043: 0.186954
# Cost after iteration 1044: 0.187151
# Cost after iteration 1045: 0.187522
# Cost after iteration 1046: 0.188340
# Cost after iteration 1047: 0.189742
# Cost after iteration 1048: 0.193039
# Cost after iteration 1049: 0.198401
# Cost after iteration 1050: 0.212941
# Cost after iteration 1051: 0.234305
# Cost after iteration 1052: 0.304933
# Cost after iteration 1053: 0.369073
# Cost after iteration 1054: 0.745393
# Cost after iteration 1055: 0.620022
# Cost after iteration 1056: 1.046112
# Cost after iteration 1057: 0.221198
# Cost after iteration 1058: 0.208438
# Cost after iteration 1059: 0.203965
# Cost after iteration 1060: 0.202461
# Cost after iteration 1061: 0.201547
# Cost after iteration 1062: 0.200806
# Cost after iteration 1063: 0.200136
# Cost after iteration 1064: 0.199513
# Cost after iteration 1065: 0.198927
# Cost after iteration 1066: 0.198375
# Cost after iteration 1067: 0.197854
# Cost after iteration 1068: 0.197362
# Cost after iteration 1069: 0.196896
# Cost after iteration 1070: 0.196456
# Cost after iteration 1071: 0.196038
# Cost after iteration 1072: 0.195643
# Cost after iteration 1073: 0.195267
# Cost after iteration 1074: 0.194910
# Cost after iteration 1075: 0.194571
# Cost after iteration 1076: 0.194249
# Cost after iteration 1077: 0.193942
# Cost after iteration 1078: 0.193650
# Cost after iteration 1079: 0.193371
# Cost after iteration 1080: 0.193105
# Cost after iteration 1081: 0.192852
# Cost after iteration 1082: 0.192609
# Cost after iteration 1083: 0.192378
# Cost after iteration 1084: 0.192156
# Cost after iteration 1085: 0.191944
# Cost after iteration 1086: 0.191741
# Cost after iteration 1087: 0.191547
# Cost after iteration 1088: 0.191360
# Cost after iteration 1089: 0.191181
# Cost after iteration 1090: 0.191010
# Cost after iteration 1091: 0.190845
# Cost after iteration 1092: 0.190686
# Cost after iteration 1093: 0.190533
# Cost after iteration 1094: 0.190386
# Cost after iteration 1095: 0.190245
# Cost after iteration 1096: 0.190109
# Cost after iteration 1097: 0.189978
# Cost after iteration 1098: 0.189851
# Cost after iteration 1099: 0.189729
# Cost after iteration 1100: 0.189611
# Cost after iteration 1101: 0.189497
# Cost after iteration 1102: 0.189386
# Cost after iteration 1103: 0.189280
# Cost after iteration 1104: 0.189177
# Cost after iteration 1105: 0.189077
# Cost after iteration 1106: 0.188980
# Cost after iteration 1107: 0.188887
# Cost after iteration 1108: 0.188796
# Cost after iteration 1109: 0.188708
# Cost after iteration 1110: 0.188622
# Cost after iteration 1111: 0.188539
# Cost after iteration 1112: 0.188459
# Cost after iteration 1113: 0.188381
# Cost after iteration 1114: 0.188305
# Cost after iteration 1115: 0.188231
# Cost after iteration 1116: 0.188159
# Cost after iteration 1117: 0.188089
# Cost after iteration 1118: 0.188020
# Cost after iteration 1119: 0.187954
# Cost after iteration 1120: 0.187889
# Cost after iteration 1121: 0.187826
# Cost after iteration 1122: 0.187765
# Cost after iteration 1123: 0.187705
# Cost after iteration 1124: 0.187646
# Cost after iteration 1125: 0.187589
# Cost after iteration 1126: 0.187533
# Cost after iteration 1127: 0.187479
# Cost after iteration 1128: 0.187426
# Cost after iteration 1129: 0.187374
# Cost after iteration 1130: 0.187323
# Cost after iteration 1131: 0.187273
# Cost after iteration 1132: 0.187224
# Cost after iteration 1133: 0.187177
# Cost after iteration 1134: 0.187130
# Cost after iteration 1135: 0.187084
# Cost after iteration 1136: 0.187039
# Cost after iteration 1137: 0.186995
# Cost after iteration 1138: 0.186952
# Cost after iteration 1139: 0.186910
# Cost after iteration 1140: 0.186869
# Cost after iteration 1141: 0.186828
# Cost after iteration 1142: 0.186788
# Cost after iteration 1143: 0.186749
# Cost after iteration 1144: 0.186711
# Cost after iteration 1145: 0.186673
# Cost after iteration 1146: 0.186636
# Cost after iteration 1147: 0.186599
# Cost after iteration 1148: 0.186564
# Cost after iteration 1149: 0.186528
# Cost after iteration 1150: 0.186494
# Cost after iteration 1151: 0.186460
# Cost after iteration 1152: 0.186426
# Cost after iteration 1153: 0.186393
# Cost after iteration 1154: 0.186361
# Cost after iteration 1155: 0.186329
# Cost after iteration 1156: 0.186297
# Cost after iteration 1157: 0.186266
# Cost after iteration 1158: 0.186235
# Cost after iteration 1159: 0.186205
# Cost after iteration 1160: 0.186176
# Cost after iteration 1161: 0.186146
# Cost after iteration 1162: 0.186117
# Cost after iteration 1163: 0.186089
# Cost after iteration 1164: 0.186061
# Cost after iteration 1165: 0.186033
# Cost after iteration 1166: 0.186006
# Cost after iteration 1167: 0.185979
# Cost after iteration 1168: 0.185952
# Cost after iteration 1169: 0.185926
# Cost after iteration 1170: 0.185900
# Cost after iteration 1171: 0.185874
# Cost after iteration 1172: 0.185849
# Cost after iteration 1173: 0.185824
# Cost after iteration 1174: 0.185800
# Cost after iteration 1175: 0.185775
# Cost after iteration 1176: 0.185752
# Cost after iteration 1177: 0.185729
# Cost after iteration 1178: 0.185708
# Cost after iteration 1179: 0.185690
# Cost after iteration 1180: 0.185679
# Cost after iteration 1181: 0.185681
# Cost after iteration 1182: 0.185713
# Cost after iteration 1183: 0.185805
# Cost after iteration 1184: 0.186040
# Cost after iteration 1185: 0.186566
# Cost after iteration 1186: 0.187818
# Cost after iteration 1187: 0.190477
# Cost after iteration 1188: 0.197275
# Cost after iteration 1189: 0.211395
# Cost after iteration 1190: 0.255452
# Cost after iteration 1191: 0.345472
# Cost after iteration 1192: 0.750941
# Cost after iteration 1193: 0.756116
# Cost after iteration 1194: 1.693843
# Cost after iteration 1195: 0.787686
# Cost after iteration 1196: 0.270660
# Cost after iteration 1197: 0.234829
# Cost after iteration 1198: 0.227876
# Cost after iteration 1199: 0.224073
# Cost after iteration 1200: 0.220838
# Cost after iteration 1201: 0.218045
# Cost after iteration 1202: 0.215608
# Cost after iteration 1203: 0.213460
# Cost after iteration 1204: 0.211552
# Cost after iteration 1205: 0.209846
# Cost after iteration 1206: 0.208311
# Cost after iteration 1207: 0.206922
# Cost after iteration 1208: 0.205658
# Cost after iteration 1209: 0.204505
# Cost after iteration 1210: 0.203447
# Cost after iteration 1211: 0.202475
# Cost after iteration 1212: 0.201577
# Cost after iteration 1213: 0.200748
# Cost after iteration 1214: 0.199978
# Cost after iteration 1215: 0.199264
# Cost after iteration 1216: 0.198599
# Cost after iteration 1217: 0.197979
# Cost after iteration 1218: 0.197400
# Cost after iteration 1219: 0.196858
# Cost after iteration 1220: 0.196351
# Cost after iteration 1221: 0.195876
# Cost after iteration 1222: 0.195429
# Cost after iteration 1223: 0.195010
# Cost after iteration 1224: 0.194616
# Cost after iteration 1225: 0.194245
# Cost after iteration 1226: 0.193895
# Cost after iteration 1227: 0.193566
# Cost after iteration 1228: 0.193254
# Cost after iteration 1229: 0.192960
# Cost after iteration 1230: 0.192683
# Cost after iteration 1231: 0.192420
# Cost after iteration 1232: 0.192171
# Cost after iteration 1233: 0.191935
# Cost after iteration 1234: 0.191711
# Cost after iteration 1235: 0.191499
# Cost after iteration 1236: 0.191297
# Cost after iteration 1237: 0.191106
# Cost after iteration 1238: 0.190924
# Cost after iteration 1239: 0.190750
# Cost after iteration 1240: 0.190585
# Cost after iteration 1241: 0.190428
# Cost after iteration 1242: 0.190278
# Cost after iteration 1243: 0.190134
# Cost after iteration 1244: 0.189997
# Cost after iteration 1245: 0.189866
# Cost after iteration 1246: 0.189741
# Cost after iteration 1247: 0.189621
# Cost after iteration 1248: 0.189506
# Cost after iteration 1249: 0.189396
# Cost after iteration 1250: 0.189290
# Cost after iteration 1251: 0.189188
# Cost after iteration 1252: 0.189091
# Cost after iteration 1253: 0.188997
# Cost after iteration 1254: 0.188906
# Cost after iteration 1255: 0.188819
# Cost after iteration 1256: 0.188735
# Cost after iteration 1257: 0.188654
# Cost after iteration 1258: 0.188576
# Cost after iteration 1259: 0.188501
# Cost after iteration 1260: 0.188428
# Cost after iteration 1261: 0.188357
# Cost after iteration 1262: 0.188289
# Cost after iteration 1263: 0.188223
# Cost after iteration 1264: 0.188159
# Cost after iteration 1265: 0.188097
# Cost after iteration 1266: 0.188037
# Cost after iteration 1267: 0.187978
# Cost after iteration 1268: 0.187921
# Cost after iteration 1269: 0.187866
# Cost after iteration 1270: 0.187812
# Cost after iteration 1271: 0.187760
# Cost after iteration 1272: 0.187709
# Cost after iteration 1273: 0.187660
# Cost after iteration 1274: 0.187611
# Cost after iteration 1275: 0.187564
# Cost after iteration 1276: 0.187518
# Cost after iteration 1277: 0.187474
# Cost after iteration 1278: 0.187430
# Cost after iteration 1279: 0.187387
# Cost after iteration 1280: 0.187345
# Cost after iteration 1281: 0.187304
# Cost after iteration 1282: 0.187264
# Cost after iteration 1283: 0.187225
# Cost after iteration 1284: 0.187187
# Cost after iteration 1285: 0.187149
# Cost after iteration 1286: 0.187112
# Cost after iteration 1287: 0.187076
# Cost after iteration 1288: 0.187041
# Cost after iteration 1289: 0.187006
# Cost after iteration 1290: 0.186972
# Cost after iteration 1291: 0.186938
# Cost after iteration 1292: 0.186905
# Cost after iteration 1293: 0.186873
# Cost after iteration 1294: 0.186841
# Cost after iteration 1295: 0.186810
# Cost after iteration 1296: 0.186779
# Cost after iteration 1297: 0.186749
# Cost after iteration 1298: 0.186719
# Cost after iteration 1299: 0.186690
# Cost after iteration 1300: 0.186661
# Cost after iteration 1301: 0.186633
# Cost after iteration 1302: 0.186605
# Cost after iteration 1303: 0.186578
# Cost after iteration 1304: 0.186551
# Cost after iteration 1305: 0.186524
# Cost after iteration 1306: 0.186497
# Cost after iteration 1307: 0.186471
# Cost after iteration 1308: 0.186446
# Cost after iteration 1309: 0.186420
# Cost after iteration 1310: 0.186395
# Cost after iteration 1311: 0.186371
# Cost after iteration 1312: 0.186346
# Cost after iteration 1313: 0.186322
# Cost after iteration 1314: 0.186299
# Cost after iteration 1315: 0.186275
# Cost after iteration 1316: 0.186252
# Cost after iteration 1317: 0.186229
# Cost after iteration 1318: 0.186206
# Cost after iteration 1319: 0.186184
# Cost after iteration 1320: 0.186162
# Cost after iteration 1321: 0.186140
# Cost after iteration 1322: 0.186118
# Cost after iteration 1323: 0.186097
# Cost after iteration 1324: 0.186076
# Cost after iteration 1325: 0.186055
# Cost after iteration 1326: 0.186034
# Cost after iteration 1327: 0.186014
# Cost after iteration 1328: 0.185993
# Cost after iteration 1329: 0.185973
# Cost after iteration 1330: 0.185953
# Cost after iteration 1331: 0.185933
# Cost after iteration 1332: 0.185914
# Cost after iteration 1333: 0.185894
# Cost after iteration 1334: 0.185875
# Cost after iteration 1335: 0.185856
# Cost after iteration 1336: 0.185837
# Cost after iteration 1337: 0.185819
# Cost after iteration 1338: 0.185800
# Cost after iteration 1339: 0.185782
# Cost after iteration 1340: 0.185764
# Cost after iteration 1341: 0.185746
# Cost after iteration 1342: 0.185728
# Cost after iteration 1343: 0.185710
# Cost after iteration 1344: 0.185692
# Cost after iteration 1345: 0.185675
# Cost after iteration 1346: 0.185658
# Cost after iteration 1347: 0.185640
# Cost after iteration 1348: 0.185623
# Cost after iteration 1349: 0.185606
# Cost after iteration 1350: 0.185590
# Cost after iteration 1351: 0.185573
# Cost after iteration 1352: 0.185556
# Cost after iteration 1353: 0.185540
# Cost after iteration 1354: 0.185523
# Cost after iteration 1355: 0.185507
# Cost after iteration 1356: 0.185491
# Cost after iteration 1357: 0.185475
# Cost after iteration 1358: 0.185459
# Cost after iteration 1359: 0.185444
# Cost after iteration 1360: 0.185428
# Cost after iteration 1361: 0.185412
# Cost after iteration 1362: 0.185397
# Cost after iteration 1363: 0.185381
# ...
# Cost after iteration 2560: 0.187342
# Cost after iteration 2561: 0.187331
# Cost after iteration 2562: 0.187324
# Cost after iteration 2563: 0.187333
# Cost after iteration 2564: 0.187350
# Cost after iteration 2565: 0.187401
# Cost after iteration 2566: 0.187463
# Cost after iteration 2567: 0.187605
# Cost after iteration 2568: 0.187763
# Cost after iteration 2569: 0.188118
# Cost after iteration 2570: 0.188483
# Cost after iteration 2571: 0.189367
# Cost after iteration 2572: 0.190215
# Cost after iteration 2573: 0.192537
# Cost after iteration 2574: 0.194619
# Cost after iteration 2575: 0.201176
# Cost after iteration 2576: 0.206270
# Cost after iteration 2577: 0.224933
# Cost after iteration 2578: 0.229025
# Cost after iteration 2579: 0.270539
# Cost after iteration 2580: 0.246272
# Cost after iteration 2581: 0.290956
# Cost after iteration 2582: 0.236408
# Cost after iteration 2583: 0.251760
# Cost after iteration 2584: 0.218023
# Cost after iteration 2585: 0.221256
# Cost after iteration 2586: 0.211309
# Cost after iteration 2587: 0.213102
# Cost after iteration 2588: 0.209072
# Cost after iteration 2589: 0.211161
# Cost after iteration 2590: 0.209314
# Cost after iteration 2591: 0.212204
# Cost after iteration 2592: 0.210891
# Cost after iteration 2593: 0.214359
# Cost after iteration 2594: 0.212491
# Cost after iteration 2595: 0.215740
# Cost after iteration 2596: 0.212649
# Cost after iteration 2597: 0.214509
# Cost after iteration 2598: 0.210169
# Cost after iteration 2599: 0.209830
# Cost after iteration 2600: 0.205080
# Cost after iteration 2601: 0.203086
# Cost after iteration 2602: 0.199145
# Cost after iteration 2603: 0.196998
# Cost after iteration 2604: 0.194468
# Cost after iteration 2605: 0.193010
# Cost after iteration 2606: 0.191632
# Cost after iteration 2607: 0.190811
# Cost after iteration 2608: 0.190096
# Cost after iteration 2609: 0.189650
# Cost after iteration 2610: 0.189265
# Cost after iteration 2611: 0.189012
# Cost after iteration 2612: 0.188786
# Cost after iteration 2613: 0.188629
# Cost after iteration 2614: 0.188483
# Cost after iteration 2615: 0.188377
# Cost after iteration 2616: 0.188273
# Cost after iteration 2617: 0.188194
# Cost after iteration 2618: 0.188115
# Cost after iteration 2619: 0.188054
# Cost after iteration 2620: 0.187990
# Cost after iteration 2621: 0.187939
# Cost after iteration 2622: 0.187886
# Cost after iteration 2623: 0.187844
# Cost after iteration 2624: 0.187799
# Cost after iteration 2625: 0.187764
# Cost after iteration 2626: 0.187726
# Cost after iteration 2627: 0.187699
# Cost after iteration 2628: 0.187668
# Cost after iteration 2629: 0.187650
# Cost after iteration 2630: 0.187626
# Cost after iteration 2631: 0.187619
# Cost after iteration 2632: 0.187605
# Cost after iteration 2633: 0.187616
# Cost after iteration 2634: 0.187615
# Cost after iteration 2635: 0.187652
# Cost after iteration 2636: 0.187672
# Cost after iteration 2637: 0.187752
# Cost after iteration 2638: 0.187806
# Cost after iteration 2639: 0.187962
# Cost after iteration 2640: 0.188072
# Cost after iteration 2641: 0.188372
# Cost after iteration 2642: 0.188582
# Cost after iteration 2643: 0.189166
# Cost after iteration 2644: 0.189562
# Cost after iteration 2645: 0.190742
# Cost after iteration 2646: 0.191512
# Cost after iteration 2647: 0.194036
# Cost after iteration 2648: 0.195607
# Cost after iteration 2649: 0.201332
# Cost after iteration 2650: 0.204372
# Cost after iteration 2651: 0.217359
# Cost after iteration 2652: 0.219563
# Cost after iteration 2653: 0.244140
# Cost after iteration 2654: 0.232422
# Cost after iteration 2655: 0.260965
# Cost after iteration 2656: 0.233435
# Cost after iteration 2657: 0.251888
# Cost after iteration 2658: 0.228944
# Cost after iteration 2659: 0.240562
# Cost after iteration 2660: 0.231219
# Cost after iteration 2661: 0.245757
# Cost after iteration 2662: 0.244109
# Cost after iteration 2663: 0.271423
# Cost after iteration 2664: 0.267781
# Cost after iteration 2665: 0.307466
# Cost after iteration 2666: 0.275346
# Cost after iteration 2667: 0.294088
# Cost after iteration 2668: 0.246495
# Cost after iteration 2669: 0.236513
# Cost after iteration 2670: 0.213473
# Cost after iteration 2671: 0.203443
# Cost after iteration 2672: 0.196459
# Cost after iteration 2673: 0.193744
# Cost after iteration 2674: 0.192025
# Cost after iteration 2675: 0.191291
# Cost after iteration 2676: 0.190718
# Cost after iteration 2677: 0.190400
# Cost after iteration 2678: 0.190125
# Cost after iteration 2679: 0.189935
# Cost after iteration 2680: 0.189763
# Cost after iteration 2681: 0.189624
# Cost after iteration 2682: 0.189495
# Cost after iteration 2683: 0.189382
# Cost after iteration 2684: 0.189275
# Cost after iteration 2685: 0.189176
# Cost after iteration 2686: 0.189082
# Cost after iteration 2687: 0.188994
# Cost after iteration 2688: 0.188909
# Cost after iteration 2689: 0.188828
# Cost after iteration 2690: 0.188750
# Cost after iteration 2691: 0.188675
# Cost after iteration 2692: 0.188603
# Cost after iteration 2693: 0.188534
# Cost after iteration 2694: 0.188467
# Cost after iteration 2695: 0.188403
# Cost after iteration 2696: 0.188340
# Cost after iteration 2697: 0.188280
# Cost after iteration 2698: 0.188221
# Cost after iteration 2699: 0.188165
# Cost after iteration 2700: 0.188110
# Cost after iteration 2701: 0.188057
# Cost after iteration 2702: 0.188005
# Cost after iteration 2703: 0.187956
# Cost after iteration 2704: 0.187907
# Cost after iteration 2705: 0.187860
# Cost after iteration 2706: 0.187815
# Cost after iteration 2707: 0.187770
# Cost after iteration 2708: 0.187727
# Cost after iteration 2709: 0.187686
# Cost after iteration 2710: 0.187646
# Cost after iteration 2711: 0.187607
# Cost after iteration 2712: 0.187569
# Cost after iteration 2713: 0.187533
# Cost after iteration 2714: 0.187497
# Cost after iteration 2715: 0.187464
# Cost after iteration 2716: 0.187432
# Cost after iteration 2717: 0.187403
# Cost after iteration 2718: 0.187375
# Cost after iteration 2719: 0.187352
# Cost after iteration 2720: 0.187330
# Cost after iteration 2721: 0.187316
# Cost after iteration 2722: 0.187305
# Cost after iteration 2723: 0.187308
# Cost after iteration 2724: 0.187317
# Cost after iteration 2725: 0.187354
# Cost after iteration 2726: 0.187402
# Cost after iteration 2727: 0.187514
# Cost after iteration 2728: 0.187643
# Cost after iteration 2729: 0.187929
# Cost after iteration 2730: 0.188235
# Cost after iteration 2731: 0.188953
# Cost after iteration 2732: 0.189664
# Cost after iteration 2733: 0.191543
# Cost after iteration 2734: 0.193279
# Cost after iteration 2735: 0.198566
# Cost after iteration 2736: 0.202975
# Cost after iteration 2737: 0.218384
# Cost after iteration 2738: 0.224501
# Cost after iteration 2739: 0.262306
# Cost after iteration 2740: 0.245407
# Cost after iteration 2741: 0.294314
# Cost after iteration 2742: 0.240925
# Cost after iteration 2743: 0.262005
# Cost after iteration 2744: 0.220634
# Cost after iteration 2745: 0.224646
# Cost after iteration 2746: 0.212244
# Cost after iteration 2747: 0.214095
# Cost after iteration 2748: 0.209383
# Cost after iteration 2749: 0.211376
# Cost after iteration 2750: 0.209294
# Cost after iteration 2751: 0.212090
# Cost after iteration 2752: 0.210770
# Cost after iteration 2753: 0.214241
# Cost after iteration 2754: 0.212493
# Cost after iteration 2755: 0.215904
# Cost after iteration 2756: 0.212970
# Cost after iteration 2757: 0.215144
# Cost after iteration 2758: 0.210882
# Cost after iteration 2759: 0.210858
# Cost after iteration 2760: 0.206014
# Cost after iteration 2761: 0.204127
# Cost after iteration 2762: 0.199961
# Cost after iteration 2763: 0.197723
# Cost after iteration 2764: 0.194980
# Cost after iteration 2765: 0.193404
# Cost after iteration 2766: 0.191898
# Cost after iteration 2767: 0.191004
# Cost after iteration 2768: 0.190228
# Cost after iteration 2769: 0.189746
# Cost after iteration 2770: 0.189334
# Cost after iteration 2771: 0.189064
# Cost after iteration 2772: 0.188826
# Cost after iteration 2773: 0.188661
# Cost after iteration 2774: 0.188510
# Cost after iteration 2775: 0.188399
# Cost after iteration 2776: 0.188293
# Cost after iteration 2777: 0.188212
# Cost after iteration 2778: 0.188131
# Cost after iteration 2779: 0.188068
# Cost after iteration 2780: 0.188003
# Cost after iteration 2781: 0.187951
# Cost after iteration 2782: 0.187896
# Cost after iteration 2783: 0.187853
# Cost after iteration 2784: 0.187806
# Cost after iteration 2785: 0.187770
# Cost after iteration 2786: 0.187730
# Cost after iteration 2787: 0.187701
# Cost after iteration 2788: 0.187667
# Cost after iteration 2789: 0.187645
# Cost after iteration 2790: 0.187619
# Cost after iteration 2791: 0.187607
# Cost after iteration 2792: 0.187589
# Cost after iteration 2793: 0.187590
# Cost after iteration 2794: 0.187584
# Cost after iteration 2795: 0.187606
# Cost after iteration 2796: 0.187617
# Cost after iteration 2797: 0.187673
# Cost after iteration 2798: 0.187711
# Cost after iteration 2799: 0.187826
# Cost after iteration 2800: 0.187908
# Cost after iteration 2801: 0.188132
# Cost after iteration 2802: 0.188293
# Cost after iteration 2803: 0.188727
# Cost after iteration 2804: 0.189031
# Cost after iteration 2805: 0.189897
# Cost after iteration 2806: 0.190482
# Cost after iteration 2807: 0.192300
# Cost after iteration 2808: 0.193476
# Cost after iteration 2809: 0.197537
# Cost after iteration 2810: 0.199953
# Cost after iteration 2811: 0.209367
# Cost after iteration 2812: 0.212911
# Cost after iteration 2813: 0.232866
# Cost after iteration 2814: 0.228635
# Cost after iteration 2815: 0.258088
# Cost after iteration 2816: 0.234891
# Cost after iteration 2817: 0.258568
# Cost after iteration 2818: 0.230551
# Cost after iteration 2819: 0.243686
# Cost after iteration 2820: 0.229183
# Cost after iteration 2821: 0.241399
# Cost after iteration 2822: 0.237252
# Cost after iteration 2823: 0.258076
# Cost after iteration 2824: 0.257595
# Cost after iteration 2825: 0.294765
# Cost after iteration 2826: 0.276878
# Cost after iteration 2827: 0.308056
# Cost after iteration 2828: 0.260625
# Cost after iteration 2829: 0.259768
# Cost after iteration 2830: 0.225804
# Cost after iteration 2831: 0.212894
# Cost after iteration 2832: 0.201039
# Cost after iteration 2833: 0.196111
# Cost after iteration 2834: 0.193115
# Cost after iteration 2835: 0.191935
# Cost after iteration 2836: 0.191091
# Cost after iteration 2837: 0.190669
# Cost after iteration 2838: 0.190316
# Cost after iteration 2839: 0.190090
# Cost after iteration 2840: 0.189890
# Cost after iteration 2841: 0.189735
# Cost after iteration 2842: 0.189594
# Cost after iteration 2843: 0.189472
# Cost after iteration 2844: 0.189359
# Cost after iteration 2845: 0.189255
# Cost after iteration 2846: 0.189157
# Cost after iteration 2847: 0.189065
# Cost after iteration 2848: 0.188977
# Cost after iteration 2849: 0.188893
# Cost after iteration 2850: 0.188813
# Cost after iteration 2851: 0.188736
# Cost after iteration 2852: 0.188662
# Cost after iteration 2853: 0.188591
# Cost after iteration 2854: 0.188522
# Cost after iteration 2855: 0.188456
# Cost after iteration 2856: 0.188392
# Cost after iteration 2857: 0.188330
# Cost after iteration 2858: 0.188270
# Cost after iteration 2859: 0.188212
# Cost after iteration 2860: 0.188156
# Cost after iteration 2861: 0.188101
# Cost after iteration 2862: 0.188049
# Cost after iteration 2863: 0.187998
# Cost after iteration 2864: 0.187948
# Cost after iteration 2865: 0.187900
# Cost after iteration 2866: 0.187854
# Cost after iteration 2867: 0.187808
# Cost after iteration 2868: 0.187765
# Cost after iteration 2869: 0.187722
# Cost after iteration 2870: 0.187681
# Cost after iteration 2871: 0.187641
# Cost after iteration 2872: 0.187602
# Cost after iteration 2873: 0.187565
# Cost after iteration 2874: 0.187529
# Cost after iteration 2875: 0.187494
# Cost after iteration 2876: 0.187461
# Cost after iteration 2877: 0.187430
# Cost after iteration 2878: 0.187400
# Cost after iteration 2879: 0.187374
# Cost after iteration 2880: 0.187349
# Cost after iteration 2881: 0.187330
# Cost after iteration 2882: 0.187314
# Cost after iteration 2883: 0.187308
# Cost after iteration 2884: 0.187307
# Cost after iteration 2885: 0.187325
# Cost after iteration 2886: 0.187353
# Cost after iteration 2887: 0.187425
# Cost after iteration 2888: 0.187511
# Cost after iteration 2889: 0.187701
# Cost after iteration 2890: 0.187912
# Cost after iteration 2891: 0.188389
# Cost after iteration 2892: 0.188879
# Cost after iteration 2893: 0.190101
# Cost after iteration 2894: 0.191265
# Cost after iteration 2895: 0.194593
# Cost after iteration 2896: 0.197547
# Cost after iteration 2897: 0.207239
# Cost after iteration 2898: 0.213727
# Cost after iteration 2899: 0.240435
# Cost after iteration 2900: 0.237785
# Cost after iteration 2901: 0.286347
# Cost after iteration 2902: 0.246963
# Cost after iteration 2903: 0.283042
# Cost after iteration 2904: 0.229040
# Cost after iteration 2905: 0.237231
# Cost after iteration 2906: 0.214862
# Cost after iteration 2907: 0.217100
# Cost after iteration 2908: 0.210074
# Cost after iteration 2909: 0.211781
# Cost after iteration 2910: 0.208811
# Cost after iteration 2911: 0.211104
# Cost after iteration 2912: 0.209598
# Cost after iteration 2913: 0.212644
# Cost after iteration 2914: 0.211195
# Cost after iteration 2915: 0.214506
# Cost after iteration 2916: 0.212209
# Cost after iteration 2917: 0.214818
# Cost after iteration 2918: 0.211266
# Cost after iteration 2919: 0.212110
# Cost after iteration 2920: 0.207644
# Cost after iteration 2921: 0.206465
# Cost after iteration 2922: 0.202129
# Cost after iteration 2923: 0.199992
# Cost after iteration 2924: 0.196775
# Cost after iteration 2925: 0.194956
# Cost after iteration 2926: 0.193034
# Cost after iteration 2927: 0.191902
# Cost after iteration 2928: 0.190874
# Cost after iteration 2929: 0.190244
# Cost after iteration 2930: 0.189699
# Cost after iteration 2931: 0.189349
# Cost after iteration 2932: 0.189043
# Cost after iteration 2933: 0.188835
# Cost after iteration 2934: 0.188648
# Cost after iteration 2935: 0.188514
# Cost after iteration 2936: 0.188389
# Cost after iteration 2937: 0.188294
# Cost after iteration 2938: 0.188202
# Cost after iteration 2939: 0.188131
# Cost after iteration 2940: 0.188059
# Cost after iteration 2941: 0.188001
# Cost after iteration 2942: 0.187942
# Cost after iteration 2943: 0.187895
# Cost after iteration 2944: 0.187846
# Cost after iteration 2945: 0.187806
# Cost after iteration 2946: 0.187764
# Cost after iteration 2947: 0.187732
# Cost after iteration 2948: 0.187697
# Cost after iteration 2949: 0.187672
# Cost after iteration 2950: 0.187643
# Cost after iteration 2951: 0.187628
# Cost after iteration 2952: 0.187607
# Cost after iteration 2953: 0.187604
# Cost after iteration 2954: 0.187594
# Cost after iteration 2955: 0.187609
# Cost after iteration 2956: 0.187614
# Cost after iteration 2957: 0.187658
# Cost after iteration 2958: 0.187686
# Cost after iteration 2959: 0.187779
# Cost after iteration 2960: 0.187844
# Cost after iteration 2961: 0.188025
# Cost after iteration 2962: 0.188155
# Cost after iteration 2963: 0.188502
# Cost after iteration 2964: 0.188747
# Cost after iteration 2965: 0.189428
# Cost after iteration 2966: 0.189892
# Cost after iteration 2967: 0.191285
# Cost after iteration 2968: 0.192196
# Cost after iteration 2969: 0.195225
# Cost after iteration 2970: 0.197093
# Cost after iteration 2971: 0.204037
# Cost after iteration 2972: 0.207428
# Cost after iteration 2973: 0.222905
# Cost after iteration 2974: 0.223444
# Cost after iteration 2975: 0.250487
# Cost after iteration 2976: 0.234223
# Cost after iteration 2977: 0.261593
# Cost after iteration 2978: 0.232929
# Cost after iteration 2979: 0.249251
# Cost after iteration 2980: 0.229635
# Cost after iteration 2981: 0.241742
# Cost after iteration 2982: 0.234919
# Cost after iteration 2983: 0.253026
# Cost after iteration 2984: 0.252438
# Cost after iteration 2985: 0.286678
# Cost after iteration 2986: 0.275890
# Cost after iteration 2987: 0.313305
# Cost after iteration 2988: 0.269280
# Cost after iteration 2989: 0.276280
# Cost after iteration 2990: 0.234478
# Cost after iteration 2991: 0.221233
# Cost after iteration 2992: 0.205280
# Cost after iteration 2993: 0.198442
# Cost after iteration 2994: 0.194178
# Cost after iteration 2995: 0.192546
# Cost after iteration 2996: 0.191433
# Cost after iteration 2997: 0.190913
# Cost after iteration 2998: 0.190487
# Cost after iteration 2999: 0.190229
# W1 = [[ 2.10351539 -1.90939265]
#  [ 2.49001187 -2.08698257]]
# b1 = [[-4.8491084 ]
#  [ 6.30266725]]
# W2 = [[-7.20237611  7.06456943]]
# b2 = [[-3.46183889]]

# %% [markdown]
# ##### __Expected Output__
# Note: the actual values can be different!
#
# ```Python
# Cost after iteration 0: 0.693148
# Cost after iteration 1: 0.693147
# Cost after iteration 2: 0.693147
# Cost after iteration 3: 0.693147
# Cost after iteration 4: 0.693147
# Cost after iteration 5: 0.693147
# ...
# Cost after iteration 2995: 0.209524
# Cost after iteration 2996: 0.208025
# Cost after iteration 2997: 0.210427
# Cost after iteration 2998: 0.208929
# Cost after iteration 2999: 0.211306
# W1 = [[ 2.14274251 -1.93155541]
#  [ 2.20268789 -2.1131799 ]]
# b1 = [[-4.83079243]
#  [ 6.2845223 ]]
# W2 = [[-7.21370685  7.0898022 ]]
# b2 = [[-3.48755239]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_nn_model(nn_model)
# Out:
#  All tests passed

# %% [markdown]
# The final model parameters can be used to find the boundary line and for making predictions.

# %% [markdown]
# <a name='ex08'></a>
# ### Exercise 8
#
# Computes probabilities using forward propagation, and make classification to 0/1 using 0.5 as the threshold.

# %%
# GRADED FUNCTION: predict

def predict(X, parameters):
    """
    Using the learned parameters, predicts a class for each example in X
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    X -- input data of size (n_x, m)
    
    Returns
    predictions -- vector of predictions of our model (blue: 0 / red: 1)
    """
    
    ### START CODE HERE ### (в‰€ 2 lines of code)
    A2, cache = forward_propagation(X, parameters)
    predictions = np.round(A2)
    ### END CODE HERE ###
    
    return predictions

# %%
X_pred = np.array([[2, 8, 2, 8], [2, 8, 8, 2]])
Y_pred = predict(X_pred, parameters)

print(f"Coordinates (in the columns):\n{X_pred}")
print(f"Predictions:\n{Y_pred}")
# Out:
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[1. 1. 0. 0.]]

# %% [markdown]
# ##### __Expected Output__
#
# ```Python
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[ True  True False False]]
# ```

# %%
w3_unittest.test_predict(predict)
# Out:
#  All tests passed

# %% [markdown]
# Let's visualize the boundary line. Do not worry if you don't understand the function `plot_decision_boundary` line by line - it simply makes prediction for some points on the plane and plots them as a contour plot (just two colors - blue and red).

# %%
def plot_decision_boundary(predict, parameters, X, Y):
    # Define bounds of the domain.
    min1, max1 = X[0, :].min()-1, X[0, :].max()+1
    min2, max2 = X[1, :].min()-1, X[1, :].max()+1
    # Define the x and y scale.
    x1grid = np.arange(min1, max1, 0.1)
    x2grid = np.arange(min2, max2, 0.1)
    # Create all of the lines and rows of the grid.
    xx, yy = np.meshgrid(x1grid, x2grid)
    # Flatten each grid to a vector.
    r1, r2 = xx.flatten(), yy.flatten()
    r1, r2 = r1.reshape((1, len(r1))), r2.reshape((1, len(r2)))
    # Vertical stack vectors to create x1,x2 input for the model.
    grid = np.vstack((r1,r2))
    # Make predictions for the grid.
    predictions = predict(grid, parameters)
    # Reshape the predictions back into a grid.
    zz = predictions.reshape(xx.shape)
    # Plot the grid of x, y and z values as a surface.
    plt.contourf(xx, yy, zz, cmap=plt.cm.Spectral.reversed())
    plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

# Plot the decision boundary.
plot_decision_boundary(predict, parameters, X, Y)
plt.title("Decision Boundary for hidden layer size " + str(n_h))
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 2')

# %% [markdown]
# That's great, you can see that more complicated classification problems can be solved with two layer neural network!

# %% [markdown]
# <a name='4'></a>
# ## 4 - Optional: Other Dataset

# %% [markdown]
# Build a slightly different dataset:

# %%
n_samples = 2000
samples, labels = make_blobs(n_samples=n_samples, 
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]), 
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0)] = 0
labels[(labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 1
X_2 = np.transpose(samples)
Y_2 = labels.reshape((1,n_samples))

plt.scatter(X_2[0, :], X_2[1, :], c=Y_2, cmap=colors.ListedColormap(['blue', 'red']));

# %% [markdown]
# Notice that when building your neural network, a number of the nodes in the hidden layer could be taken as a parameter. Try to change this parameter and investigate the results:

# %%
# parameters_2 = nn_model(X_2, Y_2, n_h=1, num_iterations=3000, learning_rate=1.2, print_cost=False)
parameters_2 = nn_model(X_2, Y_2, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=False)
# parameters_2 = nn_model(X_2, Y_2, n_h=15, num_iterations=3000, learning_rate=1.2, print_cost=False)

# This function will call predict function 
plot_decision_boundary(predict, parameters_2, X_2, Y_2)
plt.title("Decision Boundary")
# Out:
# Text(0.5, 1.0, 'Decision Boundary')

# %% [markdown]
# You can see that there are some misclassified points - real-world datasets are usually linearly inseparable, and there will be a small percentage of errors. More than that, you do not want to build a model that fits too closely, almost exactly to a particular set of data - it may fail to predict future observations. This problem is known as **overfitting**.

# %% [markdown]
# Congrats on finishing this programming assignment!
